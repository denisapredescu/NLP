# %% [markdown]
# # Lab 1. Tehnici de bază în prelucrarea textelor

# %% [markdown]
# ## Regex

# %% [markdown]
# Expresiile regulate reprezintă un șir de caractere care definesc un șablon⁠ de căutare.
#
# Ele sunt utile pentru căutarea anumitor șabloane în text și de asemenea, pentru normalizarea textelor - https://www.w3schools.com/python/python_regex.asp

# %%
import re

text = """
Praise for The Rain in Portugal
 
“Nothing in Billy Collins’s twelfth book . . . is exactly what readers might expect, and that’s the charm of this collection.”—The Washington Post
 
“This new collection shows [Collins] at his finest. . . . Certain to please his large readership and a good place for readers new to Collins to begin.”—Library Journal. 
 
“Disarmingly playful and wistfully candid.”—Booklist
Buy new:$38.65
No Import Fees Deposit & $13.01 Shipping to Romania Details -12.3.
"""

# %% [markdown]
# Exemplu de utilizare: utilizând metoda `re.sub` ștergem toate caracterele diferite de literele mari și mici ale alfabetului englez, apoi normalizăm toate secvențele de caractere de tip spațiu consecutive la un singur spațiu.

# %%
cleaned_text = re.sub("[^A-Za-z]", " ", text)
cleaned_text = re.sub("\s+", " ", cleaned_text)
print(cleaned_text)
# Out:
#  Praise for The Rain in Portugal Nothing in Billy Collins s twelfth book is exactly what readers might expect and that s the charm of this collection The Washington Post This new collection shows Collins at his finest Certain to please his large readership and a good place for readers new to Collins to begin Library Journal Disarmingly playful and wistfully candid Booklist Buy new No Import Fees Deposit Shipping to Romania Details

# %% [markdown]
# Pentru testarea pattern-urilor putem folosi https://regex101.com/.

# %% [markdown]
# ### Funcția `finditer`

# %% [markdown]
# Această funcție găsește un pattern într-un șir de caractere și returnează un iterator ce generează obiecte de tip Match cu toate potrivirile.

# %%
import re

s = 'Readability counts.'
pattern = r'[aeoui]'

matches = re.finditer(pattern, s)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(1, 2), match='e'>
# <re.Match object; span=(2, 3), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(6, 7), match='i'>
# <re.Match object; span=(8, 9), match='i'>
# <re.Match object; span=(13, 14), match='o'>
# <re.Match object; span=(14, 15), match='u'>

# %% [markdown]
# Exemplu: căutăm toate numerele float sau int, împreună cu pozițiile și valorile lor. Aici folosim metode `compile()` pentru a compila expresia regulată sub forma de string într-un pattern de tip regex.

# %%
pattern = re.compile("[+-]?(\d+\.)?\d+")
for match in pattern.finditer(text):
    print(match, "--> valoarea căutată începe de la caracterul nr.", match.start(), ", și este ", match.group())
# Out:
# <re.Match object; span=(418, 423), match='38.65'> --> valoarea căutată începe de la caracterul nr. 418 , și este  38.65
# <re.Match object; span=(450, 455), match='13.01'> --> valoarea căutată începe de la caracterul nr. 450 , și este  13.01
# <re.Match object; span=(484, 489), match='-12.3'> --> valoarea căutată începe de la caracterul nr. 484 , și este  -12.3

# %% [markdown]
# ## Encodings

# %% [markdown]
# Codificarea (encoding-ul) unui text poate varia, în funcție de limbă și este un element foarte mportant când lucrăm cu texte.
#
# Python foloseste standardul 'utf-8' pentru limba română, și nu numai.
#
# Următorul exemplu este preluat dintr-o subtitrare (.srt) din limba rusă, dar nu este encodat in utf-8. Așadar dacă vom încerca să îl citim fără să specificăm tipul de encoding, vom primi următoarea eroare:

# %%
with open('encoded_text.txt', "r") as fin:
    content = fin.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-56-368e81b8ed85> in <module>
#       1 with open('encoded_text.txt', "r") as fin:
# ----> 2     content = fin.read()
#       3     print(content)
#
# /usr/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xdd in position 34: invalid continuation byte

# %% [markdown]
# Putem detecta encoding-ul folosit cu librăria `chardet`:

# %%
! pip install chardet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: chardet in /usr/local/lib/python3.8/dist-packages (4.0.0)

# %%
import chardet

with open('encoded_text.txt', "rb") as f:
    rawdata = f.read()
    result = chardet.detect(rawdata)
    extracted_encoding = result['encoding']
    print("Encoding-ul acestui fișier este: ", extracted_encoding)
# Out:
# Encoding-ul acestui fișier este:  windows-1251

# %% [markdown]
# Cu encoding-ul potrivit, acum fișierul se poate citi:

# %%
with open('encoded_text.txt', "r", encoding="windows-1251") as fin:
    content = fin.read()
    print(content)
# Out:
# 1
# 00:00:05,100 --> 00:00:10,860
# Это были тяжелые времена. Рим находился под господством коррумпированного Папы и сомнительных законов
#
# 2
# 00:00:10,960 --> 00:00:13,820
# игр власти и междоусобной борьбы
#
# 3
# 00:00:15,660 --> 00:00:20,310
# Синьоры начинали жестокие сражения с единственной целью – накопить состояние
#
# 4
# 00:00:21,640 --> 00:00:24,950
# А тем временем, простые люди ели не каждый день
#
# 5
# 00:00:30,090 --> 00:00:36,040
# Любовь была темой для поэтов, но редко упоминалась в свадебных клятвах
#
# 6
# 00:00:36,940 --> 00:00:42,140
# Женщин отдавали в жены мужчинам, которых они едва знали, не говоря уже о любви
#
# 7
# 00:00:43,040 --> 00:00:47,980
# В этом мире, жестоком и несправедливом, я повстречала двух молодых людей

# %% [markdown]
# Putem, dacă vrem, să salvam conținutul în format utf-8, deoarece acest format este default pentru python și nu mai trebie specificat la deschidere:

# %%
with open('encoded_text.txt', 'r', encoding=extracted_encoding) as fin:
    content = fin.read()
with open('utf8_text.txt', 'w', encoding='utf-8') as fout:
    fout.write(content)

# %%
with open('utf8_text.txt', "r") as fin:
    content = fin.read()
    print(content)
# Out:
# 1
# 00:00:05,100 --> 00:00:10,860
# Это были тяжелые времена. Рим находился под господством коррумпированного Папы и сомнительных законов
#
# 2
# 00:00:10,960 --> 00:00:13,820
# игр власти и междоусобной борьбы
#
# 3
# 00:00:15,660 --> 00:00:20,310
# Синьоры начинали жестокие сражения с единственной целью – накопить состояние
#
# 4
# 00:00:21,640 --> 00:00:24,950
# А тем временем, простые люди ели не каждый день
#
# 5
# 00:00:30,090 --> 00:00:36,040
# Любовь была темой для поэтов, но редко упоминалась в свадебных клятвах
#
# 6
# 00:00:36,940 --> 00:00:42,140
# Женщин отдавали в жены мужчинам, которых они едва знали, не говоря уже о любви
#
# 7
# 00:00:43,040 --> 00:00:47,980
# В этом мире, жестоком и несправедливом, я повстречала двух молодых людей

# %% [markdown]
# ## Non-standard files (PDF, Word, etc.)

# %% [markdown]
# Putem citi texte din documente word folosind librăria `doc2txt`.

# %%
# !pip install docx2txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: docx2txt in /usr/local/lib/python3.8/dist-packages (0.8)

# %%
import docx2txt
my_text = docx2txt.process("soup.docx")
print(my_text)
# Out:
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.
#
#
#
# These instructions illustrate all major features of Beautiful Soup 4, with examples. I show you what the library is good for, how it works, how to use it, how to make it do what you want, and what to do when it violates your expectations.
#
#
#
# This document covers Beautiful Soup version 4.10.0. The examples in this documentation were written for Python 3.8.
#
#
#
# You might be looking for the documentation for Beautiful Soup 3. If so, you should know that Beautiful Soup 3 is no longer being developed and that all support for it was dropped on December 31, 2020. If you want to learn about the differences between Beautiful Soup 3 and Beautiful Soup 4, see Porting code to BS4.
#
#
#
# This documentation has been translated into other languages by Beautiful Soup users:

# %% [markdown]
# Putem citi pdf-uri care sunt salvate ca texte (nu poze), de exemplu, cu librăria `pdfplumber`:

# %%
! pip install pdfplumber
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pdfplumber
#   Downloading pdfplumber-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 KB 4.6 MB/s eta 0:00:00
# Collecting Wand>=0.6.10
#   Downloading Wand-0.6.11-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 KB 17.0 MB/s eta 0:00:00
# Collecting Pillow>=9.1
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 103.8 MB/s eta 0:00:00
# Collecting pdfminer.six==20221105
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 113.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six==20221105->pdfplumber) (3.0.1)
# Collecting cryptography>=36.0.0
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 115.2 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Installing collected packages: Wand, Pillow, cryptography, pdfminer.six, pdfplumber
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Pillow-9.4.0 Wand-0.6.11 cryptography-39.0.1 pdfminer.six-20221105 pdfplumber-0.8.0

# %%
import pdfplumber
with pdfplumber.open('soup.pdf') as pdf:
    for page in pdf.pages:
        print(page.extract_text())
# Out:
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite
# parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly
# saves programmers hours or days of work.
# These instructions illustrate all major features of Beautiful Soup 4, with examples. I show you what the
# library is good for, how it works, how to use it, how to make it do what you want, and what to do when
# it violates your expectations.
# This document covers Beautiful Soup version 4.10.0. The examples in this documentation were written
# for Python 3.8.
# You might be looking for the documentation for Beautiful Soup 3. If so, you should know that Beautiful
# Soup 3 is no longer being developed and that all support for it was dropped on December 31, 2020. If
# you want to learn about the differences between Beautiful Soup 3 and Beautiful Soup 4, see Porting
# code to BS4.
# This documentation has been translated into other languages by Beautiful Soup users:

# %% [markdown]
# ## Web scraping

# %% [markdown]
# Scraping-ul se referă la o mulțime de metode prin care putem descărca date nestructurate din mediul web. Pe noi ne interesează datele text, pe care după preluarea din mediul online le putem procesa și stoca într-o formă structurată.

# %% [markdown]
# Ca prim exemplu de scraping vom incerca următorul task: pornind de la site-ul de programare competitiva "infoarena.ro" dorim pentru un utilizator sa descarcam informatii despre toate submisiile efectuate de acesta.
#
# Exemplu pagină de submisii: https://www.infoarena.ro/monitor?user=iordache.bogdan
#
# Pentru a realiza un request care să întoarca conținutul paginii putem folosi librăria `requests`:

# %%
! pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)

# %%
import requests

def get_submissions_page(user):
    return requests.get(f"https://www.infoarena.ro/monitor?user={user}")

# %%
html = get_submissions_page("iordache.bogdan").content

# %% [markdown]
# Observăm că folosind metoda de mai sus putem descarca întreg conținutul HTML al paginii. Pentru a extrage informații utile trebuie să parsam acest conținut. Pentru aceasta vom folosi biblioteca [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/):

# %%
import bs4

def parse_html(html):
    return bs4.BeautifulSoup(html, "html.parser")

# %% [markdown]
# Având conținutul parsat, putem determina acum câte submisii are în total acest utilizator:

# %%
import re

soup = parse_html(html)

# cautam un span care are clasa "count", in acest span se afla numarul de submisii
submission_count_text = soup.find("span", class_="count").text
print(submission_count_text)
# Out:
#  (5033 rezultate)

# %% [markdown]
# Pentru a extrage doar numărul din această înșiruire de caractere ne putem folosi de regex:

# %%
submission_count = int(re.search(r"\d+", submission_count_text).group())
print(submission_count)
# Out:
# 5033

# %% [markdown]
# Observăm că aceste submisii sunt împărtite în mai multe pagini (paginarea rezultatelor).
#
# De asemenea, link-ul următor: https://www.infoarena.ro/monitor?user=iordache.bogdan&display_entries=250&first_entry=100 ne returnează 250 de submisii, incepând cu submisia cu numarul 100.
#
# Putem modifica metoda `get_submissions_page` astfel:

# %%
def get_submissions_page(user, display_entries=None, first_entry=None):
    req_string = f"https://www.infoarena.ro/monitor?user={user}"
    if display_entries is not None:
        req_string += f"&display_entries={display_entries}"
    if first_entry is not None:
        req_string += f"&first_entry={first_entry}"

    return requests.get(req_string)

# %% [markdown]
# Și putem implementa o funcție care returnează informații despre toate submisiile unui utilizator:

# %%
from tqdm import tqdm
import pandas as pd
import pdb

def scrape_submissions(user):
    # determinam numarul total de submisii
    html = get_submissions_page(user).content
    soup = parse_html(html)
    submission_count_text = soup.find("span", class_="count").text
    submission_count = int(re.search(r"\d+", submission_count_text).group())
    print(submission_count)

    # vom salva in acest dictionar datele despre submisiile extrase, structura aceasta
    # ne va ajuta ulterior sa construim un tabel (dataframe) folosind pandas
    d = {
        "id": [],
        "problema": [],
        "url_problema": [],
        "url_sursa": [],
        "data": [],
        "puncte": [],
    }

    # accesam pagini cu submisii in grupuri de 250
    for first_entry in tqdm(range(0, submission_count, 250)):
        html = get_submissions_page(user, display_entries=250, first_entry=first_entry).content
        soup = parse_html(html)

        # selectam toate liniile de tabel (tr)
        lines = soup.select("table.monitor tbody tr")

        for line in lines:
            # selectam celulele de pe aceasta linie
            cells = [cell for cell in line.select("td")]

            # extragem link-urile pentru problema si codul sursa
            try:
                url_problema = cells[2].select_one("a")["href"]
                url_sursa = cells[4].select_one("a")["href"]
            except Exception:  # daca vreun link nu exista ignoram linia
                continue
            
            d["id"].append(cells[0].text)
            d["problema"].append(cells[2].text)
            d["url_problema"].append(url_problema)
            d["url_sursa"].append(url_sursa)
            d["data"].append(cells[5].text)

            try:
                puncte = int(re.search(r"\d+", cells[6].text).group())
            except Exception:
                puncte = 0
            d["puncte"].append(puncte)

    return pd.DataFrame(d)

# %%
df_submissions = scrape_submissions("iordache.bogdan")
# Out:
# 5033
# 100%|██████████| 21/21 [00:22<00:00,  1.05s/it]

# %%
df_submissions.head()
# Out:
#          id                problema      url_problema  \
# 0  #2971352                    Atac    /problema/atac
# 1  #2971346                    Atac    /problema/atac
# 2  #2971294                  Pirati  /problema/pirati
# 3  #2970859  Lowest Common Ancestor     /problema/lca
# 4  #2970853  Lowest Common Ancestor     /problema/lca
#
#                                 url_sursa                data  puncte
# 0  /job_detail/2971352?action=view-source  27 ian 23 01:27:44     100
# 1  /job_detail/2971346?action=view-source  27 ian 23 01:07:30      20
# 2  /job_detail/2971294?action=view-source  26 ian 23 23:18:14     100
# 3  /job_detail/2970859?action=view-source  25 ian 23 23:42:36     100
# 4  /job_detail/2970853?action=view-source  25 ian 23 23:19:15     100

# %%
df_submissions.to_csv("submissions.csv", index=False)

# %% [markdown]
# Exemplu scriere/citire fisier JSON:

# %%
import json

vec = [
    {"title": "example_1", "size": 7},
    {"title": "example_2", "size": 3},
    {"title": "example_3", "size": 8},
]

with open("example.json", "w") as f:
    json.dump(vec, f, indent=4)

# %%
with open("example.json", "r") as f:
    vec = json.load(f)
print(vec)
# Out:
# [{'title': 'example_1', 'size': 7}, {'title': 'example_2', 'size': 3}, {'title': 'example_3', 'size': 8}]

# %% [markdown]
# Un alt mod de a face scraping este sa folosim biblioteca pandas pentru a ne extrage tabele html, transformandu-le in DataFrame-uri, pe care le putem manipula foarte usor. Un exemplu util este extragerea sărbătorilor legale romanesti, din anul 2022, de pe https://www.timeanddate.com/.

# %%
! pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (4.9.2)

# %%
import pandas as pd

tables_df = pd.read_html('https://www.timeanddate.com/holidays/romania/2022?hol=1')
df = tables_df[0]

# Il putem curata prin a sterge liniile nule si modifica coloanele de la tuplul "(Date, Date)" -> "Date"
df = df.dropna(axis='index')
df.columns = ['Date', 'Day', 'Name', 'Type']

# Reindexam tabelul
df = df.reset_index(drop="True")

# Afisam primele 5 randuri
df.head()
# Out:
#      Date       Day                      Name              Type
# 0   Jan 1  Saturday            New Year's Day  National holiday
# 1   Jan 2    Sunday  Day after New Year's Day  National holiday
# 2  Jan 24    Monday           Unification Day  National holiday
# 3  Feb 19  Saturday   Constantin Brancusi Day        Observance
# 4  Feb 24  Thursday                 Dragobete        Observance

# %%
# Daca vrem se vedem sarbatorile care se nimeresc in ziua de luni putem face o selecție în dataframe
df_luni = df.loc[df["Day"] == "Monday"]
df_luni
# Out:
#       Date     Day                       Name                        Type
# 2   Jan 24  Monday            Unification Day            National holiday
# 10  Apr 25  Monday     Orthodox Easter Monday  National holiday, Orthodox
# 19  Jun 13  Monday  Orthodox Pentecost Monday  National holiday, Orthodox
# 23  Aug 15  Monday              St Mary's Day            National holiday
# 25  Oct 31  Monday                  Halloween                  Observance
# 33  Dec 26  Monday    Second day of Christmas            National holiday

# %% [markdown]
# Putem salva rezultatul (la fel ca orice dicționar de python) intr-un json, ca alternativa la DataFrame - acest lucru poate fi util într-o aplicație pentru comunicarea cu front-end-ul.

# %%
import json
json_str = df.to_json(orient='records')
json_result = json.loads(json_str)

with open('holidays.json', 'w', encoding='utf8') as fout:
    json.dump(json_result, fout, indent=4, sort_keys=True, ensure_ascii=False)

# %% [markdown]
# Alte biblioteci utile pentru scraping:
#  * [scrapy](https://scrapy.org/) (folosit in special pentru web crawling)
#  * [selenium](https://selenium-python.readthedocs.io/) (folosit pentru a simula activitatea din browser, utilizat in special in scrierea de teste pentru aplicatii front-end)

# %% [markdown]
# ## TASK: IMDb scraping

# %% [markdown]
# 1. Pornind de la lista cu cele mai populare 250 de filme de pe IMDb ([https://www.imdb.com/chart/top/](https://www.imdb.com/chart/top/)), identificati pentru toate aceste filme link-ul catre pagina sa de recenzii.
#
# Exemplu: aici se gaseste pagina cu recenzii pentru "The Shawshank Redemption": [https://www.imdb.com/title/tt0111161/reviews](https://www.imdb.com/title/tt0111161/reviews)

# %%
import pandas as pd
import pdb
import bs4
import re
import requests
import json
from IPython.display import display_html

def get_page(link):
    # headers = {'Accept-Language': 'ro-RO,ro;q=0.9,en-US;q=0.8,en;q=0.7'}
    headers = {'Accept-Language': 'en-US;q=0.8,en;q=0.7'}
    return requests.get(link, headers=headers)

def parse_html(html):
    return bs4.BeautifulSoup(html, "html.parser")

def scrape_movies():
    html = get_page(f"https://www.imdb.com/chart/top/").content
    soup = parse_html(html)

    movies_review_link = {
        "title": [],
        "url_review": []
    }
    movies_list = soup.select("table.chart tbody.lister-list tr")

    for movie_line in movies_list:
        try:
            info = movie_line.select("td.titleColumn")[0]
            title = info.select_one("a").text
            review = info.select_one("a")["href"] + "reviews"
        except Exception:  # daca vreun link nu exista ignoram linia
            continue
        
        movies_review_link["title"].append(title)
        movies_review_link["url_review"].append(f"https://www.imdb.com" + review)

    return pd.DataFrame(movies_review_link)

df_movies = scrape_movies()
display_html(df_movies.head())

json_str = df_movies.to_json(orient='records')    
movies = json.loads(json_str)  #salvez datele intr-un json pentru a fi usor de utilizat la exercitiile urmatoare
# Out:
#   <div id="df-4bf1f4e8-a3fe-4276-b625-d63964ac20e7">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>url_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Shawshank Redemption</td>
#       <td>https://www.imdb.com/title/tt0111161/reviews</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Godfather</td>
#       <td>https://www.imdb.com/title/tt0068646/reviews</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The Dark Knight</td>
#       <td>https://www.imdb.com/title/tt0468569/reviews</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The Godfather Part II</td>
#       <td>https://www.imdb.com/title/tt0071562/reviews</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>12 Angry Men</td>
#       <td>https://www.imdb.com/title/tt0050083/reviews</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-4bf1f4e8-a3fe-4276-b625-d63964ac20e7')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-4bf1f4e8-a3fe-4276-b625-d63964ac20e7 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-4bf1f4e8-a3fe-4276-b625-d63964ac20e7');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>

# %% [markdown]
# 2. Pentru fiecare film colectati date despre recenziile sale (titlu, text, rating, data, utlizator, etc.)

# %%
import pandas as pd
import pdb
import re
import requests    
import json
from IPython.display import display_html

reviews = []
def select_movie_reviews():   # functie care ia pe rand fiecare film si ii afiseaza intr-un dataframe recenziile sale
    for movie in movies:
      print(movie["title"], end=" ")
      df_reviews = scrape_reviews_info(movie)
      reviews.extend(json.loads(df_reviews.to_json(orient='records'))) # jsonul de recenzii este necesar pentru exercitiuul 3
      display_html(df_reviews.head())    

def scrape_reviews_info(movie):
    html = get_page(movie["url_review"]).content
    soup = parse_html(html)

    reviews = {
        "titlu": [],
        "text": [],
        "rating": [],
        "data": [],
        "utilizator": [],
        "film": []
    }
    review_list = soup.select("div.lister div.lister-list div.review-container div.lister-item-content")

    for review in review_list:
      titlu = re.sub("\n", "", review.select_one("a").text)     # titlul era primit din html cu \n la final
      text = review.select_one("div.content div.text").text
      try:
        rating = int(review.select_one("span.rating-other-user-rating span").text)
      except Exception:  # daca userul nu a oferit un rating
        rating = "-"
      data = review.select_one("div.display-name-date span.review-date").text
      utilizator = review.select_one("div.display-name-date span.display-name-link a").text

      reviews["titlu"].append(titlu)
      reviews["text"].append(text)
      reviews["rating"].append(rating)
      reviews["data"].append(data)
      reviews["utilizator"].append(utilizator)
      reviews["film"].append(movie["title"])

    return pd.DataFrame(reviews)

select_movie_reviews()
# Out:
# The Shawshank Redemption
#   <div id="df-4bd53c33-1357-4697-a89f-e224cc2c8444">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Some birds aren't meant to be caged.</td>
#       <td>The Shawshank Redemption is written and direct...</td>
#       <td>10</td>
#       <td>24 July 2010</td>
#       <td>hitchcockthelegend</td>
#       <td>The Shawshank Redemption</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>An incredible movie. One that lives with you.</td>
#       <td>It is no wonder that the film has such a high ...</td>
#       <td>10</td>
#       <td>17 February 2021</td>
#       <td>Sleepin_Dragon</td>
#       <td>The Shawshank Redemption</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Don't Rent Shawshank.</td>
#       <td>I'm trying to save you money; this is the last...</td>
#       <td>10</td>
#       <td>21 November 2005</td>
#       <td>EyeDunno</td>
#       <td>The Shawshank Redemption</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>This is How Movies Should Be Made</td>
#       <td>This movie is not your ordinary Hollywood flic...</td>
#       <td>10</td>
#       <td>18 February 2008</td>
#       <td>alexkolokotronis</td>
#       <td>The Shawshank Redemption</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>A classic piece of unforgettable film-making.</td>
#       <td>In its Oscar year, Shawshank Redemption (writt...</td>
#       <td>10</td>
#       <td>10 February 2006</td>
#       <td>kaspen12</td>
#       <td>The Shawshank Redemption</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-4bd53c33-1357-4697-a89f-e224cc2c8444')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-4bd53c33-1357-4697-a89f-e224cc2c8444 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-4bd53c33-1357-4697-a89f-e224cc2c8444');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Godfather
#   <div id="df-dbc426c8-f304-45bb-9e48-5bfe495465bc">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Pinnacle Of Flawless Films!</td>
#       <td>'The Godfather' is the pinnacle of flawless fi...</td>
#       <td>-</td>
#       <td>20 June 2014</td>
#       <td>CalRhys</td>
#       <td>The Godfather</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>An offer so good, I couldn't refuse</td>
#       <td>It is now past 1 PM and I just finished watchi...</td>
#       <td>10</td>
#       <td>1 April 2019</td>
#       <td>andrewburgereviews</td>
#       <td>The Godfather</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>For Me, This Is The Definitive Film</td>
#       <td>This isn't just a beautifully crafted gangster...</td>
#       <td>10</td>
#       <td>11 February 2018</td>
#       <td>gogoschka-1</td>
#       <td>The Godfather</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>One of the best of all time.</td>
#       <td>A masterclass in film making, is The Godfather...</td>
#       <td>10</td>
#       <td>6 February 2021</td>
#       <td>Sleepin_Dragon</td>
#       <td>The Godfather</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>An Iconic Film</td>
#       <td>Tell me a movie that is more famous than this....</td>
#       <td>10</td>
#       <td>21 June 2008</td>
#       <td>alexkolokotronis</td>
#       <td>The Godfather</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-dbc426c8-f304-45bb-9e48-5bfe495465bc')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-dbc426c8-f304-45bb-9e48-5bfe495465bc button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-dbc426c8-f304-45bb-9e48-5bfe495465bc');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Dark Knight
#   <div id="df-450f34b8-402a-4945-9d8a-5dea783b6ec2">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Dark Knight</td>
#       <td>Confidently directed, dark, brooding, and pack...</td>
#       <td>-</td>
#       <td>12 February 2020</td>
#       <td>MrHeraclius</td>
#       <td>The Dark Knight</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Batman of our dreams! So much more than a...</td>
#       <td>I got to see The Dark Knight on Wednesday nigh...</td>
#       <td>10</td>
#       <td>20 July 2008</td>
#       <td>Smells_Like_Cheese</td>
#       <td>The Dark Knight</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>This town deserves a better class of criminal!</td>
#       <td>This movie is a work of art. The finest sequel...</td>
#       <td>10</td>
#       <td>17 February 2021</td>
#       <td>dseferaj</td>
#       <td>The Dark Knight</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MASTERPIECE</td>
#       <td>It is just what you want for the best movie. G...</td>
#       <td>10</td>
#       <td>7 October 2019</td>
#       <td>Aegontheconqueror</td>
#       <td>The Dark Knight</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Mindblowing</td>
#       <td>I thought I was getting a clever comic book mo...</td>
#       <td>10</td>
#       <td>24 November 2019</td>
#       <td>RayCharles81</td>
#       <td>The Dark Knight</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-450f34b8-402a-4945-9d8a-5dea783b6ec2')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-450f34b8-402a-4945-9d8a-5dea783b6ec2 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-450f34b8-402a-4945-9d8a-5dea783b6ec2');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Godfather Part II
#   <div id="df-0be90709-8529-42f3-b112-257f1a7843e8">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Breathtaking in its scope and tragic grandeur...</td>
#       <td>Coppola's masterpiece is rivaled only by "The ...</td>
#       <td>10</td>
#       <td>10 March 2001</td>
#       <td>Nazi_Fighter_David</td>
#       <td>The Godfather Part II</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Greatest Sequel During the Cinema's History</td>
#       <td>"The Godfather, Part II" is excellent just lik...</td>
#       <td>-</td>
#       <td>13 October 2001</td>
#       <td>tfrizzell</td>
#       <td>The Godfather Part II</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A masterpiece that can never be beaten...</td>
#       <td>One of the all time greats. Or probably the al...</td>
#       <td>10</td>
#       <td>9 August 2019</td>
#       <td>umunir-36959</td>
#       <td>The Godfather Part II</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The Greatest Film Ever Made</td>
#       <td>The original Godfather is a brilliant work. It...</td>
#       <td>10</td>
#       <td>7 May 1999</td>
#       <td>DanB-4</td>
#       <td>The Godfather Part II</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Terrific continuation of the "Godfather" seri...</td>
#       <td>This sequel is just as terrific as the first f...</td>
#       <td>10</td>
#       <td>23 August 2003</td>
#       <td>MovieAddict2016</td>
#       <td>The Godfather Part II</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-0be90709-8529-42f3-b112-257f1a7843e8')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-0be90709-8529-42f3-b112-257f1a7843e8 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-0be90709-8529-42f3-b112-257f1a7843e8');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# 12 Angry Men
#   <div id="df-d380f6fa-d102-49aa-af64-92f98e74a0db">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The over-used term "classic movie" really com...</td>
#       <td>This once-in-a-generation masterpiece simply h...</td>
#       <td>-</td>
#       <td>12 August 2002</td>
#       <td>uds3</td>
#       <td>12 Angry Men</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>No Dissonance</td>
#       <td>This film deserves to be on anyone's list of t...</td>
#       <td>-</td>
#       <td>26 April 2001</td>
#       <td>tedg</td>
#       <td>12 Angry Men</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>One of the great theatrical examples of what ...</td>
#       <td>Theater at its best is practically impossible ...</td>
#       <td>10</td>
#       <td>20 March 2017</td>
#       <td>mark.waltz</td>
#       <td>12 Angry Men</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>What a Character-Study Is Meant to Be.</td>
#       <td>Intense courtroom drama which has 12 very diff...</td>
#       <td>-</td>
#       <td>8 June 2002</td>
#       <td>tfrizzell</td>
#       <td>12 Angry Men</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Dont judge by the age!</td>
#       <td>For a while I was not very receptive to watchi...</td>
#       <td>10</td>
#       <td>31 January 2020</td>
#       <td>henriquelrf</td>
#       <td>12 Angry Men</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-d380f6fa-d102-49aa-af64-92f98e74a0db')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-d380f6fa-d102-49aa-af64-92f98e74a0db button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-d380f6fa-d102-49aa-af64-92f98e74a0db');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# Schindler's List
#   <div id="df-4215304d-b59e-44b8-9074-1dc7f8136984">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A three hour film that feels too short</td>
#       <td>This film tells the story of Nazi officer Oska...</td>
#       <td>-</td>
#       <td>19 October 2009</td>
#       <td>Gordon-11</td>
#       <td>Schindler's List</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Awesome</td>
#       <td>The movie started out pretty innocently, and f...</td>
#       <td>10</td>
#       <td>17 October 2005</td>
#       <td>ebiros2</td>
#       <td>Schindler's List</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bring me the heads of Hitler, Himmler, Eichma...</td>
#       <td>Schindler's List is undoubtedly the best Holoc...</td>
#       <td>10</td>
#       <td>9 September 2013</td>
#       <td>Fella_shibby</td>
#       <td>Schindler's List</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>What he hell is wrong with the people that co...</td>
#       <td>To all the ppl on the 1st four review pages, u...</td>
#       <td>9</td>
#       <td>16 August 2017</td>
#       <td>padawanmovies</td>
#       <td>Schindler's List</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>A SINGULAR ACHIEVEMENT</td>
#       <td>I have only ever seen this film once, I only e...</td>
#       <td>-</td>
#       <td>11 December 2000</td>
#       <td>vtburns</td>
#       <td>Schindler's List</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-4215304d-b59e-44b8-9074-1dc7f8136984')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-4215304d-b59e-44b8-9074-1dc7f8136984 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-4215304d-b59e-44b8-9074-1dc7f8136984');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Lord of the Rings: The Return of the King
#   <div id="df-c8a7f90f-ef98-464a-bcf7-7f045ccce8ae">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The best trilogy in the history of cinema</td>
#       <td>Best movie in the trilogy and sealed in the be...</td>
#       <td>10</td>
#       <td>28 September 2020</td>
#       <td>auuwws</td>
#       <td>The Lord of the Rings: The Return of the King</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>All Good Things come to an End!</td>
#       <td>All the threads of Tolkien's magnum opus come ...</td>
#       <td>10</td>
#       <td>22 November 2006</td>
#       <td>OttoVonB</td>
#       <td>The Lord of the Rings: The Return of the King</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Great</td>
#       <td>Wonderful on every level. Love the characters ...</td>
#       <td>-</td>
#       <td>15 February 2020</td>
#       <td>MrHeraclius</td>
#       <td>The Lord of the Rings: The Return of the King</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Nothing better</td>
#       <td>The greatest tragedy of the human race is that...</td>
#       <td>10</td>
#       <td>2 November 2020</td>
#       <td>diffguy</td>
#       <td>The Lord of the Rings: The Return of the King</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Pretty much outstanding</td>
#       <td>I admit it, I love all three Lord of the Rings...</td>
#       <td>10</td>
#       <td>9 March 2011</td>
#       <td>TheLittleSongbird</td>
#       <td>The Lord of the Rings: The Return of the King</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-c8a7f90f-ef98-464a-bcf7-7f045ccce8ae')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-c8a7f90f-ef98-464a-bcf7-7f045ccce8ae button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-c8a7f90f-ef98-464a-bcf7-7f045ccce8ae');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# Pulp Fiction
#   <div id="df-ff8a311f-19d3-461d-b2e5-0b8f92bdb97e">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The masterpiece without a message</td>
#       <td>One of the early scenes in "Pulp Fiction" feat...</td>
#       <td>10</td>
#       <td>17 November 2005</td>
#       <td>kylopod</td>
#       <td>Pulp Fiction</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Shotguns</td>
#       <td>I like the bit with the cheeseburger. It makes...</td>
#       <td>10</td>
#       <td>30 March 2020</td>
#       <td>bevo-13678</td>
#       <td>Pulp Fiction</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A masterpiece of screenwriting</td>
#       <td>This is Tarantino's masterpiece, there's no ot...</td>
#       <td>10</td>
#       <td>12 November 2020</td>
#       <td>SebMoz</td>
#       <td>Pulp Fiction</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The rebirth of a genre – and film history</td>
#       <td>I can only speak for myself, but I had never s...</td>
#       <td>10</td>
#       <td>24 July 2014</td>
#       <td>gogoschka-1</td>
#       <td>Pulp Fiction</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The most rewatchable movie of all time</td>
#       <td>Possibly the most influential movie made in hi...</td>
#       <td>10</td>
#       <td>10 April 2020</td>
#       <td>gautammayya</td>
#       <td>Pulp Fiction</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-ff8a311f-19d3-461d-b2e5-0b8f92bdb97e')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-ff8a311f-19d3-461d-b2e5-0b8f92bdb97e button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-ff8a311f-19d3-461d-b2e5-0b8f92bdb97e');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Lord of the Rings: The Fellowship of the Ring
#   <div id="df-491e34ca-2769-4577-9a8f-2cd6f2a2b3bf">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>First, And Still The Best Of LOTR</td>
#       <td>Here is one film that lived up to its hype, an...</td>
#       <td>10</td>
#       <td>7 March 2006</td>
#       <td>ccthemovieman-1</td>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>How the hell did they film this thing</td>
#       <td>An incredible feat\nEnthrals anew every time\n...</td>
#       <td>10</td>
#       <td>7 March 2021</td>
#       <td>mosquitobite</td>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The Fellowship of the Ring: Not just a Movie,...</td>
#       <td>The first part of the Lord of the Rings trilog...</td>
#       <td>10</td>
#       <td>14 April 2006</td>
#       <td>bonnie91</td>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Great</td>
#       <td>It is my firm belief that the standard version...</td>
#       <td>-</td>
#       <td>15 February 2020</td>
#       <td>MrHeraclius</td>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>An absolutely incredible film!</td>
#       <td>Simply incredible. Never before have I seen a ...</td>
#       <td>10</td>
#       <td>2 May 2002</td>
#       <td>NRGWasp</td>
#       <td>The Lord of the Rings: The Fellowship of the Ring</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-491e34ca-2769-4577-9a8f-2cd6f2a2b3bf')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-491e34ca-2769-4577-9a8f-2cd6f2a2b3bf button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-491e34ca-2769-4577-9a8f-2cd6f2a2b3bf');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# The Good, the Bad and the Ugly
#   <div id="df-a717d0b8-0979-4963-b815-2aad45a4b131">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>For a girl who doesn't enjoy westerns much, t...</td>
#       <td>Gosh, The Good, the Bad, and the Ugly, I final...</td>
#       <td>10</td>
#       <td>29 June 2006</td>
#       <td>Smells_Like_Cheese</td>
#       <td>The Good, the Bad and the Ugly</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Brutal, brilliant, and one of the best Wester...</td>
#       <td>A sprawling Western epic that follows the adve...</td>
#       <td>10</td>
#       <td>16 April 2001</td>
#       <td>MadReviewer</td>
#       <td>The Good, the Bad and the Ugly</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sergio Leone's penultimate Italian-western; a...</td>
#       <td>...and though those last several words could a...</td>
#       <td>10</td>
#       <td>1 January 2004</td>
#       <td>Quinoa1984</td>
#       <td>The Good, the Bad and the Ugly</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>The Good, the Better, the Best</td>
#       <td>The Good, the Bad and the Ugly or the Good, th...</td>
#       <td>10</td>
#       <td>19 February 2009</td>
#       <td>murtaza_mma</td>
#       <td>The Good, the Bad and the Ugly</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>the greatest of the great!</td>
#       <td>I wasn't sure if I was going to comment on thi...</td>
#       <td>10</td>
#       <td>24 August 2005</td>
#       <td>spider89119</td>
#       <td>The Good, the Bad and the Ugly</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-a717d0b8-0979-4963-b815-2aad45a4b131')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-a717d0b8-0979-4963-b815-2aad45a4b131 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-a717d0b8-0979-4963-b815-2aad45a4b131');
# ...
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-221e1247-1314-4486-b6a6-d6a9aca0ce95 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-221e1247-1314-4486-b6a6-d6a9aca0ce95');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# Aladdin
#   <div id="df-0935dc97-81ab-4704-832b-87094c339291">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>I'd put it in with the Disney classics</td>
#       <td>Aladdin is such an awesome move that still get...</td>
#       <td>10</td>
#       <td>23 November 2003</td>
#       <td>Smells_Like_Cheese</td>
#       <td>Aladdin</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Great songs and a good villain make "Aladdin"...</td>
#       <td>This movie has three elements that are importa...</td>
#       <td>9</td>
#       <td>23 October 2004</td>
#       <td>Boba_Fett1138</td>
#       <td>Aladdin</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Robin Williams, Great Songs Make This One Of ...</td>
#       <td>I can think of three quick reasons why this ha...</td>
#       <td>10</td>
#       <td>12 January 2007</td>
#       <td>ccthemovieman-1</td>
#       <td>Aladdin</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Forever a favorite of mine ...</td>
#       <td>I will never forget the first time I watched "...</td>
#       <td>10</td>
#       <td>19 December 2011</td>
#       <td>ElMaruecan82</td>
#       <td>Aladdin</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Vintage Robin Williams</td>
#       <td>I did not care to see this movie, but I was su...</td>
#       <td>10</td>
#       <td>5 September 2001</td>
#       <td>aesgaard41</td>
#       <td>Aladdin</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-0935dc97-81ab-4704-832b-87094c339291')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-0935dc97-81ab-4704-832b-87094c339291 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-0935dc97-81ab-4704-832b-87094c339291');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# Gandhi
#   <div id="df-be08c150-836e-4b54-a0ee-67dac6515e5a">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Took nearly twenty years to make - not a sing...</td>
#       <td>Here indeed is one of the great films of the 2...</td>
#       <td>9</td>
#       <td>24 December 2001</td>
#       <td>khatcher-2</td>
#       <td>Gandhi</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Old-Time Hollywood Epic Redux.</td>
#       <td>The life of the legendary man from India (domi...</td>
#       <td>-</td>
#       <td>24 September 2005</td>
#       <td>tfrizzell</td>
#       <td>Gandhi</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Attenborough offers a tour de force performances</td>
#       <td>There is a sanctimonious air to the films of S...</td>
#       <td>10</td>
#       <td>19 June 2005</td>
#       <td>Nazi_Fighter_David</td>
#       <td>Gandhi</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Beautiful Film</td>
#       <td>"The object of this massive tribute died as he...</td>
#       <td>8</td>
#       <td>29 January 2002</td>
#       <td>Rod-88</td>
#       <td>Gandhi</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>A true epic, in every sense of the word</td>
#       <td>Very, VERY few films have had the distinct abi...</td>
#       <td>-</td>
#       <td>15 September 2003</td>
#       <td>quixoboy</td>
#       <td>Gandhi</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-be08c150-836e-4b54-a0ee-67dac6515e5a')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-be08c150-836e-4b54-a0ee-67dac6515e5a button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-be08c150-836e-4b54-a0ee-67dac6515e5a');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>
# Dances with Wolves
#   <div id="df-a59f7b91-7735-4944-a952-daf0e76aee50">
#     <div class="colab-df-container">
#       <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>titlu</th>
#       <th>text</th>
#       <th>rating</th>
#       <th>data</th>
#       <th>utilizator</th>
#       <th>film</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fantastic</td>
#       <td>It's hard to think of blockbuster films that p...</td>
#       <td>9</td>
#       <td>12 April 2021</td>
#       <td>gbill-74877</td>
#       <td>Dances with Wolves</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>It is the trail of a true human being. I thin...</td>
#       <td>Dances With Wolves Is directed by Kevin Costne...</td>
#       <td>10</td>
#       <td>10 October 2010</td>
#       <td>hitchcockthelegend</td>
#       <td>Dances with Wolves</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>A legacy for all time...</td>
#       <td>I rember seeing this shortly after it came out...</td>
#       <td>10</td>
#       <td>14 February 2019</td>
#       <td>bheadher</td>
#       <td>Dances with Wolves</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>I love this movie!</td>
#       <td>It's hard for me to believe that fourteen year...</td>
#       <td>10</td>
#       <td>9 November 2004</td>
#       <td>PhilipJames1980</td>
#       <td>Dances with Wolves</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The best film of all time</td>
#       <td>Many people regard a lot of films as "top clas...</td>
#       <td>10</td>
#       <td>28 May 2006</td>
#       <td>mattrochman</td>
#       <td>Dances with Wolves</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#       <button class="colab-df-convert" onclick="convertToInteractive('df-a59f7b91-7735-4944-a952-daf0e76aee50')"
#               title="Convert this dataframe to an interactive table."
#               style="display:none;">
#
#   <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"
#        width="24px">
#     <path d="M0 0h24v24H0V0z" fill="none"/>
#     <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>
#   </svg>
#       </button>
#
#   <style>
#     .colab-df-container {
#       display:flex;
#       flex-wrap:wrap;
#       gap: 12px;
#     }
#
#     .colab-df-convert {
#       background-color: #E8F0FE;
#       border: none;
#       border-radius: 50%;
#       cursor: pointer;
#       display: none;
#       fill: #1967D2;
#       height: 32px;
#       padding: 0 0 0 0;
#       width: 32px;
#     }
#
#     .colab-df-convert:hover {
#       background-color: #E2EBFA;
#       box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);
#       fill: #174EA6;
#     }
#
#     [theme=dark] .colab-df-convert {
#       background-color: #3B4455;
#       fill: #D2E3FC;
#     }
#
#     [theme=dark] .colab-df-convert:hover {
#       background-color: #434B5C;
#       box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);
#       filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));
#       fill: #FFFFFF;
#     }
#   </style>
#
#       <script>
#         const buttonEl =
#           document.querySelector('#df-a59f7b91-7735-4944-a952-daf0e76aee50 button.colab-df-convert');
#         buttonEl.style.display =
#           google.colab.kernel.accessAllowed ? 'block' : 'none';
#
#         async function convertToInteractive(key) {
#           const element = document.querySelector('#df-a59f7b91-7735-4944-a952-daf0e76aee50');
#           const dataTable =
#             await google.colab.kernel.invokeFunction('convertToInteractive',
#                                                      [key], {});
#           if (!dataTable) return;
#
#           const docLinkHtml = 'Like what you see? Visit the ' +
#             '<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'
#             + ' to learn more about interactive tables.';
#           element.innerHTML = '';
#           dataTable['output_type'] = 'display_data';
#           await google.colab.output.renderOutput(dataTable, element);
#           const docLink = document.createElement('div');
#           docLink.innerHTML = docLinkHtml;
#           element.appendChild(docLink);
#         }
#       </script>
#     </div>
#   </div>

# %% [markdown]
# 3. Creati un dataset de recenzii, pentru fiecare recenzie stocati:
#  * filmul caruia ii apartine
#  * titlul recenziei
#  * textul recenziei
#  * ratingul
#  * data
#  * utilizator
#
#  Salvati datasetul intr-un fisier JSON.

# %%
import json

# la exercitiul precedent am creat deja jsonul dorit
# acum trebuie doar sa il salvez intr-un fisier

with open('reviews.json', 'w') as fout:
    json.dump(reviews, fout, indent=4)

# %% [markdown]
# 4. Pe o pagina cu recenzii putem gasi un numar mic de astfel de date. Butonul de "Load more" de la final, cand este apasat, produce un request care returneaza HTML-ul urmatoarelor recenzii. Folosind aceasta logica colectati automat pentru fiecare film un numar mai mare de recenzii.

# %%
import json

reviews = []
def movies_reviews():   
    for movie in movies:
      more_than_one_load(movie)

    with open('more_reviews.json', 'w') as fout:
        json.dump(reviews, fout, indent=4)

def more_than_one_load(movie):
    html = get_page(movie["url_review"]).content
    soup = parse_html(html)
    pages = 5
    loads = 1
    while soup is not None and pages >= loads:
      print(f"{movie['title']} {loads} load(s) => {number_of_reviews_displayed(soup)} reviews loaded")
      select_reviews(soup, movie)
      try:
        pagination_key = soup.find("div", class_="load-more-data").attrs['data-key']
        html = get_page(f"{movie['url_review']}/_ajax?ref_=undefined&paginationKey={pagination_key}").content
        soup = parse_html(html)
      except Exception:
        break
      loads += 1

def number_of_reviews_displayed(soup):
    review = soup.select("div.lister-list div.review-container div.lister-item-content")
    return len(review)

def select_reviews(soup, movie):
    review_list = soup.select("div.lister-list div.review-container div.lister-item-content")
    for review in review_list:
      titlu = re.sub("\n", "", review.select_one("a").text)    
      text = review.select_one("div.content div.text").text
      try:
        rating = int(review.select_one("span.rating-other-user-rating span").text)
      except Exception:  # daca userul nu a oferit un rating
        rating = "-"
      data = review.select_one("div.display-name-date span.review-date").text
      utilizator = review.select_one("div.display-name-date span.display-name-link a").text

      reviews.append({
          "titlu":titlu,
          "text":text,
          "rating":rating,
          "data":data,
          "utilizator":utilizator,
          "film":movie['title']
      })

movies_reviews()
# Out:
# The Shawshank Redemption 1 load(s) => 25 reviews loaded
# The Shawshank Redemption 2 load(s) => 25 reviews loaded
# The Shawshank Redemption 3 load(s) => 25 reviews loaded
# The Shawshank Redemption 4 load(s) => 24 reviews loaded
# The Shawshank Redemption 5 load(s) => 25 reviews loaded
# The Godfather 1 load(s) => 25 reviews loaded
# The Godfather 2 load(s) => 25 reviews loaded
# The Godfather 3 load(s) => 25 reviews loaded
# The Godfather 4 load(s) => 25 reviews loaded
# The Godfather 5 load(s) => 25 reviews loaded
# The Dark Knight 1 load(s) => 25 reviews loaded
# The Dark Knight 2 load(s) => 25 reviews loaded
# The Dark Knight 3 load(s) => 25 reviews loaded
# The Dark Knight 4 load(s) => 25 reviews loaded
# The Dark Knight 5 load(s) => 25 reviews loaded
# The Godfather Part II 1 load(s) => 25 reviews loaded
# The Godfather Part II 2 load(s) => 25 reviews loaded
# The Godfather Part II 3 load(s) => 25 reviews loaded
# The Godfather Part II 4 load(s) => 25 reviews loaded
# The Godfather Part II 5 load(s) => 25 reviews loaded
# 12 Angry Men 1 load(s) => 25 reviews loaded
# 12 Angry Men 2 load(s) => 25 reviews loaded
# 12 Angry Men 3 load(s) => 25 reviews loaded
# 12 Angry Men 4 load(s) => 25 reviews loaded
# 12 Angry Men 5 load(s) => 25 reviews loaded
# Schindler's List 1 load(s) => 25 reviews loaded
# Schindler's List 2 load(s) => 25 reviews loaded
# Schindler's List 3 load(s) => 25 reviews loaded
# Schindler's List 4 load(s) => 25 reviews loaded
# Schindler's List 5 load(s) => 25 reviews loaded
# The Lord of the Rings: The Return of the King 1 load(s) => 25 reviews loaded
# The Lord of the Rings: The Return of the King 2 load(s) => 25 reviews loaded
# The Lord of the Rings: The Return of the King 3 load(s) => 25 reviews loaded
# The Lord of the Rings: The Return of the King 4 load(s) => 25 reviews loaded
# The Lord of the Rings: The Return of the King 5 load(s) => 25 reviews loaded
# Pulp Fiction 1 load(s) => 25 reviews loaded
# Pulp Fiction 2 load(s) => 25 reviews loaded
# Pulp Fiction 3 load(s) => 25 reviews loaded
# Pulp Fiction 4 load(s) => 25 reviews loaded
# Pulp Fiction 5 load(s) => 25 reviews loaded
# The Lord of the Rings: The Fellowship of the Ring 1 load(s) => 25 reviews loaded
# The Lord of the Rings: The Fellowship of the Ring 2 load(s) => 25 reviews loaded
# The Lord of the Rings: The Fellowship of the Ring 3 load(s) => 25 reviews loaded
# The Lord of the Rings: The Fellowship of the Ring 4 load(s) => 25 reviews loaded
# The Lord of the Rings: The Fellowship of the Ring 5 load(s) => 25 reviews loaded
# The Good, the Bad and the Ugly 1 load(s) => 24 reviews loaded
# The Good, the Bad and the Ugly 2 load(s) => 24 reviews loaded
# The Good, the Bad and the Ugly 3 load(s) => 25 reviews loaded
# The Good, the Bad and the Ugly 4 load(s) => 25 reviews loaded
# The Good, the Bad and the Ugly 5 load(s) => 25 reviews loaded
# Forrest Gump 1 load(s) => 25 reviews loaded
# Forrest Gump 2 load(s) => 25 reviews loaded
# Forrest Gump 3 load(s) => 25 reviews loaded
# Forrest Gump 4 load(s) => 25 reviews loaded
# Forrest Gump 5 load(s) => 25 reviews loaded
# Fight Club 1 load(s) => 25 reviews loaded
# Fight Club 2 load(s) => 25 reviews loaded
# Fight Club 3 load(s) => 25 reviews loaded
# Fight Club 4 load(s) => 25 reviews loaded
# Fight Club 5 load(s) => 25 reviews loaded
# The Lord of the Rings: The Two Towers 1 load(s) => 25 reviews loaded
# The Lord of the Rings: The Two Towers 2 load(s) => 25 reviews loaded
# The Lord of the Rings: The Two Towers 3 load(s) => 25 reviews loaded
# The Lord of the Rings: The Two Towers 4 load(s) => 25 reviews loaded
# The Lord of the Rings: The Two Towers 5 load(s) => 25 reviews loaded
# Inception 1 load(s) => 25 reviews loaded
# Inception 2 load(s) => 25 reviews loaded
# Inception 3 load(s) => 25 reviews loaded
# Inception 4 load(s) => 25 reviews loaded
# Inception 5 load(s) => 25 reviews loaded
# Star Wars: Episode V - The Empire Strikes Back 1 load(s) => 25 reviews loaded
# Star Wars: Episode V - The Empire Strikes Back 2 load(s) => 25 reviews loaded
# Star Wars: Episode V - The Empire Strikes Back 3 load(s) => 25 reviews loaded
# Star Wars: Episode V - The Empire Strikes Back 4 load(s) => 25 reviews loaded
# Star Wars: Episode V - The Empire Strikes Back 5 load(s) => 25 reviews loaded
# The Matrix 1 load(s) => 25 reviews loaded
# The Matrix 2 load(s) => 25 reviews loaded
# The Matrix 3 load(s) => 25 reviews loaded
# The Matrix 4 load(s) => 25 reviews loaded
# The Matrix 5 load(s) => 25 reviews loaded
# Goodfellas 1 load(s) => 25 reviews loaded
# Goodfellas 2 load(s) => 25 reviews loaded
# Goodfellas 3 load(s) => 25 reviews loaded
# Goodfellas 4 load(s) => 25 reviews loaded
# Goodfellas 5 load(s) => 25 reviews loaded
# One Flew Over the Cuckoo's Nest 1 load(s) => 25 reviews loaded
# One Flew Over the Cuckoo's Nest 2 load(s) => 25 reviews loaded
# One Flew Over the Cuckoo's Nest 3 load(s) => 25 reviews loaded
# One Flew Over the Cuckoo's Nest 4 load(s) => 24 reviews loaded
# One Flew Over the Cuckoo's Nest 5 load(s) => 25 reviews loaded
# Se7en 1 load(s) => 25 reviews loaded
# Se7en 2 load(s) => 25 reviews loaded
# Se7en 3 load(s) => 25 reviews loaded
# Se7en 4 load(s) => 24 reviews loaded
# Se7en 5 load(s) => 24 reviews loaded
# Seven Samurai 1 load(s) => 25 reviews loaded
# Seven Samurai 2 load(s) => 25 reviews loaded
# Seven Samurai 3 load(s) => 25 reviews loaded
# Seven Samurai 4 load(s) => 25 reviews loaded
# Seven Samurai 5 load(s) => 25 reviews loaded
# It's a Wonderful Life 1 load(s) => 25 reviews loaded
# It's a Wonderful Life 2 load(s) => 25 reviews loaded
# It's a Wonderful Life 3 load(s) => 25 reviews loaded
# It's a Wonderful Life 4 load(s) => 25 reviews loaded
# It's a Wonderful Life 5 load(s) => 25 reviews loaded
# The Silence of the Lambs 1 load(s) => 25 reviews loaded
# The Silence of the Lambs 2 load(s) => 25 reviews loaded
# The Silence of the Lambs 3 load(s) => 25 reviews loaded
# The Silence of the Lambs 4 load(s) => 25 reviews loaded
# The Silence of the Lambs 5 load(s) => 25 reviews loaded
# Saving Private Ryan 1 load(s) => 25 reviews loaded
# Saving Private Ryan 2 load(s) => 25 reviews loaded
# Saving Private Ryan 3 load(s) => 25 reviews loaded
# Saving Private Ryan 4 load(s) => 25 reviews loaded
# Saving Private Ryan 5 load(s) => 25 reviews loaded
# City of God 1 load(s) => 25 reviews loaded
# City of God 2 load(s) => 24 reviews loaded
# City of God 3 load(s) => 24 reviews loaded
# City of God 4 load(s) => 25 reviews loaded
# City of God 5 load(s) => 25 reviews loaded
# Interstellar 1 load(s) => 25 reviews loaded
# Interstellar 2 load(s) => 25 reviews loaded
# Interstellar 3 load(s) => 25 reviews loaded
# Interstellar 4 load(s) => 25 reviews loaded
# Interstellar 5 load(s) => 25 reviews loaded
# Life Is Beautiful 1 load(s) => 25 reviews loaded
# Life Is Beautiful 2 load(s) => 24 reviews loaded
# Life Is Beautiful 3 load(s) => 24 reviews loaded
# Life Is Beautiful 4 load(s) => 25 reviews loaded
# Life Is Beautiful 5 load(s) => 25 reviews loaded
# The Green Mile 1 load(s) => 25 reviews loaded
# The Green Mile 2 load(s) => 25 reviews loaded
# The Green Mile 3 load(s) => 25 reviews loaded
# The Green Mile 4 load(s) => 24 reviews loaded
# The Green Mile 5 load(s) => 25 reviews loaded
# Star Wars: Episode IV - A New Hope 1 load(s) => 25 reviews loaded
# Star Wars: Episode IV - A New Hope 2 load(s) => 24 reviews loaded
# Star Wars: Episode IV - A New Hope 3 load(s) => 25 reviews loaded
# Star Wars: Episode IV - A New Hope 4 load(s) => 25 reviews loaded
# Star Wars: Episode IV - A New Hope 5 load(s) => 25 reviews loaded
# Terminator 2: Judgment Day 1 load(s) => 25 reviews loaded
# Terminator 2: Judgment Day 2 load(s) => 25 reviews loaded
# Terminator 2: Judgment Day 3 load(s) => 25 reviews loaded
# Terminator 2: Judgment Day 4 load(s) => 25 reviews loaded
# Terminator 2: Judgment Day 5 load(s) => 25 reviews loaded
# Back to the Future 1 load(s) => 25 reviews loaded
# Back to the Future 2 load(s) => 25 reviews loaded
# Back to the Future 3 load(s) => 25 reviews loaded
# Back to the Future 4 load(s) => 25 reviews loaded
# Back to the Future 5 load(s) => 25 reviews loaded
# Spirited Away 1 load(s) => 25 reviews loaded
# Spirited Away 2 load(s) => 25 reviews loaded
# Spirited Away 3 load(s) => 25 reviews loaded
# Spirited Away 4 load(s) => 25 reviews loaded
# Spirited Away 5 load(s) => 25 reviews loaded
# The Pianist 1 load(s) => 25 reviews loaded
# The Pianist 2 load(s) => 25 reviews loaded
# The Pianist 3 load(s) => 25 reviews loaded
# The Pianist 4 load(s) => 25 reviews loaded
# The Pianist 5 load(s) => 25 reviews loaded
# Psycho 1 load(s) => 25 reviews loaded
# Psycho 2 load(s) => 25 reviews loaded
# Psycho 3 load(s) => 25 reviews loaded
# Psycho 4 load(s) => 24 reviews loaded
# Psycho 5 load(s) => 23 reviews loaded
# Parasite 1 load(s) => 24 reviews loaded
# Parasite 2 load(s) => 25 reviews loaded
# Parasite 3 load(s) => 25 reviews loaded
# Parasite 4 load(s) => 25 reviews loaded
# Parasite 5 load(s) => 25 reviews loaded
# Léon: The Professional 1 load(s) => 25 reviews loaded
# Léon: The Professional 2 load(s) => 25 reviews loaded
# Léon: The Professional 3 load(s) => 25 reviews loaded
# Léon: The Professional 4 load(s) => 25 reviews loaded
# Léon: The Professional 5 load(s) => 25 reviews loaded
# The Lion King 1 load(s) => 25 reviews loaded
# The Lion King 2 load(s) => 25 reviews loaded
# The Lion King 3 load(s) => 25 reviews loaded
# The Lion King 4 load(s) => 25 reviews loaded
# The Lion King 5 load(s) => 25 reviews loaded
# Gladiator 1 load(s) => 25 reviews loaded
# Gladiator 2 load(s) => 25 reviews loaded
# Gladiator 3 load(s) => 24 reviews loaded
# Gladiator 4 load(s) => 25 reviews loaded
# Gladiator 5 load(s) => 25 reviews loaded
# American History X 1 load(s) => 25 reviews loaded
# American History X 2 load(s) => 25 reviews loaded
# American History X 3 load(s) => 24 reviews loaded
# American History X 4 load(s) => 25 reviews loaded
# American History X 5 load(s) => 25 reviews loaded
# The Departed 1 load(s) => 25 reviews loaded
# The Departed 2 load(s) => 25 reviews loaded
# The Departed 3 load(s) => 25 reviews loaded
# The Departed 4 load(s) => 25 reviews loaded
# The Departed 5 load(s) => 25 reviews loaded
# The Usual Suspects 1 load(s) => 25 reviews loaded
# The Usual Suspects 2 load(s) => 25 reviews loaded
# The Usual Suspects 3 load(s) => 25 reviews loaded
# The Usual Suspects 4 load(s) => 22 reviews loaded
# The Usual Suspects 5 load(s) => 25 reviews loaded
# The Prestige 1 load(s) => 25 reviews loaded
# The Prestige 2 load(s) => 25 reviews loaded
# The Prestige 3 load(s) => 25 reviews loaded
# The Prestige 4 load(s) => 25 reviews loaded
# The Prestige 5 load(s) => 25 reviews loaded
# Whiplash 1 load(s) => 25 reviews loaded
# Whiplash 2 load(s) => 25 reviews loaded
# Whiplash 3 load(s) => 25 reviews loaded
# Whiplash 4 load(s) => 25 reviews loaded
# Whiplash 5 load(s) => 25 reviews loaded
# Casablanca 1 load(s) => 25 reviews loaded
# Casablanca 2 load(s) => 25 reviews loaded
# Casablanca 3 load(s) => 25 reviews loaded
# Casablanca 4 load(s) => 25 reviews loaded
# Casablanca 5 load(s) => 24 reviews loaded
# Harakiri 1 load(s) => 25 reviews loaded
# Harakiri 2 load(s) => 25 reviews loaded
# Harakiri 3 load(s) => 25 reviews loaded
# Harakiri 4 load(s) => 25 reviews loaded
# Harakiri 5 load(s) => 25 reviews loaded
# Grave of the Fireflies 1 load(s) => 25 reviews loaded
# Grave of the Fireflies 2 load(s) => 25 reviews loaded
# Grave of the Fireflies 3 load(s) => 25 reviews loaded
# Grave of the Fireflies 4 load(s) => 25 reviews loaded
# Grave of the Fireflies 5 load(s) => 25 reviews loaded
# The Intouchables 1 load(s) => 25 reviews loaded
# The Intouchables 2 load(s) => 25 reviews loaded
# The Intouchables 3 load(s) => 25 reviews loaded
# The Intouchables 4 load(s) => 25 reviews loaded
# The Intouchables 5 load(s) => 25 reviews loaded
# Modern Times 1 load(s) => 25 reviews loaded
# Modern Times 2 load(s) => 25 reviews loaded
# Modern Times 3 load(s) => 25 reviews loaded
# Modern Times 4 load(s) => 24 reviews loaded
# Modern Times 5 load(s) => 25 reviews loaded
# Once Upon a Time in the West 1 load(s) => 25 reviews loaded
# Once Upon a Time in the West 2 load(s) => 25 reviews loaded
# Once Upon a Time in the West 3 load(s) => 25 reviews loaded
# Once Upon a Time in the West 4 load(s) => 25 reviews loaded
# Once Upon a Time in the West 5 load(s) => 25 reviews loaded
# Rear Window 1 load(s) => 25 reviews loaded
# Rear Window 2 load(s) => 25 reviews loaded
# Rear Window 3 load(s) => 25 reviews loaded
# Rear Window 4 load(s) => 25 reviews loaded
# Rear Window 5 load(s) => 25 reviews loaded
# Cinema Paradiso 1 load(s) => 25 reviews loaded
# Cinema Paradiso 2 load(s) => 25 reviews loaded
# Cinema Paradiso 3 load(s) => 25 reviews loaded
# Cinema Paradiso 4 load(s) => 25 reviews loaded
# Cinema Paradiso 5 load(s) => 25 reviews loaded
# Alien 1 load(s) => 25 reviews loaded
# Alien 2 load(s) => 25 reviews loaded
# Alien 3 load(s) => 25 reviews loaded
# Alien 4 load(s) => 25 reviews loaded
# Alien 5 load(s) => 25 reviews loaded
# City Lights 1 load(s) => 25 reviews loaded
# City Lights 2 load(s) => 25 reviews loaded
# City Lights 3 load(s) => 25 reviews loaded
# City Lights 4 load(s) => 25 reviews loaded
# City Lights 5 load(s) => 25 reviews loaded
# Apocalypse Now 1 load(s) => 24 reviews loaded
# Apocalypse Now 2 load(s) => 24 reviews loaded
# Apocalypse Now 3 load(s) => 25 reviews loaded
# Apocalypse Now 4 load(s) => 25 reviews loaded
# Apocalypse Now 5 load(s) => 25 reviews loaded
# Memento 1 load(s) => 25 reviews loaded
# Memento 2 load(s) => 25 reviews loaded
# Memento 3 load(s) => 25 reviews loaded
# Memento 4 load(s) => 25 reviews loaded
# Memento 5 load(s) => 25 reviews loaded
# Django Unchained 1 load(s) => 25 reviews loaded
# Django Unchained 2 load(s) => 25 reviews loaded
# Django Unchained 3 load(s) => 25 reviews loaded
# Django Unchained 4 load(s) => 24 reviews loaded
# Django Unchained 5 load(s) => 25 reviews loaded
# Indiana Jones and the Raiders of the Lost Ark 1 load(s) => 25 reviews loaded
# Indiana Jones and the Raiders of the Lost Ark 2 load(s) => 25 reviews loaded
# Indiana Jones and the Raiders of the Lost Ark 3 load(s) => 25 reviews loaded
# Indiana Jones and the Raiders of the Lost Ark 4 load(s) => 25 reviews loaded
# Indiana Jones and the Raiders of the Lost Ark 5 load(s) => 25 reviews loaded
# WALL·E 1 load(s) => 25 reviews loaded
# WALL·E 2 load(s) => 25 reviews loaded
# WALL·E 3 load(s) => 25 reviews loaded
# WALL·E 4 load(s) => 25 reviews loaded
# WALL·E 5 load(s) => 25 reviews loaded
# The Lives of Others 1 load(s) => 25 reviews loaded
# The Lives of Others 2 load(s) => 25 reviews loaded
# The Lives of Others 3 load(s) => 25 reviews loaded
# The Lives of Others 4 load(s) => 25 reviews loaded
# The Lives of Others 5 load(s) => 25 reviews loaded
# Sunset Blvd. 1 load(s) => 25 reviews loaded
# Sunset Blvd. 2 load(s) => 25 reviews loaded
# Sunset Blvd. 3 load(s) => 25 reviews loaded
# Sunset Blvd. 4 load(s) => 25 reviews loaded
# Sunset Blvd. 5 load(s) => 25 reviews loaded
# Paths of Glory 1 load(s) => 25 reviews loaded
# Paths of Glory 2 load(s) => 25 reviews loaded
# Paths of Glory 3 load(s) => 25 reviews loaded
# Paths of Glory 4 load(s) => 25 reviews loaded
# Paths of Glory 5 load(s) => 25 reviews loaded
# The Shining 1 load(s) => 25 reviews loaded
# The Shining 2 load(s) => 25 reviews loaded
# The Shining 3 load(s) => 25 reviews loaded
# The Shining 4 load(s) => 25 reviews loaded
# The Shining 5 load(s) => 25 reviews loaded
# The Great Dictator 1 load(s) => 25 reviews loaded
# The Great Dictator 2 load(s) => 25 reviews loaded
# The Great Dictator 3 load(s) => 25 reviews loaded
# The Great Dictator 4 load(s) => 25 reviews loaded
# The Great Dictator 5 load(s) => 24 reviews loaded
# Avengers: Infinity War 1 load(s) => 25 reviews loaded
# Avengers: Infinity War 2 load(s) => 25 reviews loaded
# Avengers: Infinity War 3 load(s) => 25 reviews loaded
# Avengers: Infinity War 4 load(s) => 25 reviews loaded
# Avengers: Infinity War 5 load(s) => 25 reviews loaded
# Witness for the Prosecution 1 load(s) => 25 reviews loaded
# Witness for the Prosecution 2 load(s) => 25 reviews loaded
# Witness for the Prosecution 3 load(s) => 25 reviews loaded
# Witness for the Prosecution 4 load(s) => 25 reviews loaded
# Witness for the Prosecution 5 load(s) => 25 reviews loaded
# Aliens 1 load(s) => 25 reviews loaded
# Aliens 2 load(s) => 25 reviews loaded
# Aliens 3 load(s) => 25 reviews loaded
# Aliens 4 load(s) => 25 reviews loaded
# Aliens 5 load(s) => 25 reviews loaded
# Spider-Man: Into the Spider-Verse 1 load(s) => 25 reviews loaded
# Spider-Man: Into the Spider-Verse 2 load(s) => 25 reviews loaded
# Spider-Man: Into the Spider-Verse 3 load(s) => 25 reviews loaded
# Spider-Man: Into the Spider-Verse 4 load(s) => 25 reviews loaded
# Spider-Man: Into the Spider-Verse 5 load(s) => 25 reviews loaded
# American Beauty 1 load(s) => 24 reviews loaded
# American Beauty 2 load(s) => 25 reviews loaded
# American Beauty 3 load(s) => 25 reviews loaded
# American Beauty 4 load(s) => 25 reviews loaded
# American Beauty 5 load(s) => 24 reviews loaded
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb 1 load(s) => 25 reviews loaded
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb 2 load(s) => 25 reviews loaded
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb 3 load(s) => 25 reviews loaded
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb 4 load(s) => 24 reviews loaded
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb 5 load(s) => 25 reviews loaded
# The Dark Knight Rises 1 load(s) => 25 reviews loaded
# The Dark Knight Rises 2 load(s) => 25 reviews loaded
# The Dark Knight Rises 3 load(s) => 25 reviews loaded
# The Dark Knight Rises 4 load(s) => 25 reviews loaded
# The Dark Knight Rises 5 load(s) => 25 reviews loaded
# Oldboy 1 load(s) => 25 reviews loaded
# Oldboy 2 load(s) => 25 reviews loaded
# Oldboy 3 load(s) => 25 reviews loaded
# Oldboy 4 load(s) => 25 reviews loaded
# Oldboy 5 load(s) => 25 reviews loaded
# Inglourious Basterds 1 load(s) => 25 reviews loaded
# Inglourious Basterds 2 load(s) => 25 reviews loaded
# Inglourious Basterds 3 load(s) => 25 reviews loaded
# Inglourious Basterds 4 load(s) => 25 reviews loaded
# Inglourious Basterds 5 load(s) => 25 reviews loaded
# Amadeus 1 load(s) => 25 reviews loaded
# Amadeus 2 load(s) => 25 reviews loaded
# Amadeus 3 load(s) => 25 reviews loaded
# Amadeus 4 load(s) => 25 reviews loaded
# Amadeus 5 load(s) => 25 reviews loaded
# Coco 1 load(s) => 25 reviews loaded
# Coco 2 load(s) => 25 reviews loaded
# Coco 3 load(s) => 25 reviews loaded
# Coco 4 load(s) => 25 reviews loaded
# Coco 5 load(s) => 25 reviews loaded
# Toy Story 1 load(s) => 24 reviews loaded
# Toy Story 2 load(s) => 25 reviews loaded
# Toy Story 3 load(s) => 24 reviews loaded
# Toy Story 4 load(s) => 25 reviews loaded
# Toy Story 5 load(s) => 25 reviews loaded
# Joker 1 load(s) => 25 reviews loaded
# Joker 2 load(s) => 25 reviews loaded
# Joker 3 load(s) => 25 reviews loaded
# Joker 4 load(s) => 25 reviews loaded
# Joker 5 load(s) => 25 reviews loaded
# Braveheart 1 load(s) => 25 reviews loaded
# Braveheart 2 load(s) => 24 reviews loaded
# Braveheart 3 load(s) => 25 reviews loaded
# Braveheart 4 load(s) => 25 reviews loaded
# Braveheart 5 load(s) => 25 reviews loaded
# The Boat 1 load(s) => 25 reviews loaded
# The Boat 2 load(s) => 25 reviews loaded
# The Boat 3 load(s) => 25 reviews loaded
# The Boat 4 load(s) => 25 reviews loaded
# The Boat 5 load(s) => 25 reviews loaded
# Avengers: Endgame 1 load(s) => 25 reviews loaded
# Avengers: Endgame 2 load(s) => 25 reviews loaded
# Avengers: Endgame 3 load(s) => 25 reviews loaded
# Avengers: Endgame 4 load(s) => 25 reviews loaded
# Avengers: Endgame 5 load(s) => 25 reviews loaded
# Princess Mononoke 1 load(s) => 25 reviews loaded
# Princess Mononoke 2 load(s) => 25 reviews loaded
# Princess Mononoke 3 load(s) => 25 reviews loaded
# Princess Mononoke 4 load(s) => 25 reviews loaded
# Princess Mononoke 5 load(s) => 24 reviews loaded
# Once Upon a Time in America 1 load(s) => 25 reviews loaded
# Once Upon a Time in America 2 load(s) => 25 reviews loaded
# Once Upon a Time in America 3 load(s) => 25 reviews loaded
# Once Upon a Time in America 4 load(s) => 25 reviews loaded
# Once Upon a Time in America 5 load(s) => 24 reviews loaded
# Good Will Hunting 1 load(s) => 24 reviews loaded
# Good Will Hunting 2 load(s) => 24 reviews loaded
# Good Will Hunting 3 load(s) => 25 reviews loaded
# Good Will Hunting 4 load(s) => 24 reviews loaded
# Good Will Hunting 5 load(s) => 24 reviews loaded
# Your Name. 1 load(s) => 25 reviews loaded
# Your Name. 2 load(s) => 25 reviews loaded
# Your Name. 3 load(s) => 25 reviews loaded
# Your Name. 4 load(s) => 25 reviews loaded
# Your Name. 5 load(s) => 25 reviews loaded
# 3 Idiots 1 load(s) => 25 reviews loaded
# 3 Idiots 2 load(s) => 25 reviews loaded
# 3 Idiots 3 load(s) => 25 reviews loaded
# 3 Idiots 4 load(s) => 25 reviews loaded
# 3 Idiots 5 load(s) => 25 reviews loaded
# Singin' in the Rain 1 load(s) => 25 reviews loaded
# Singin' in the Rain 2 load(s) => 25 reviews loaded
# Singin' in the Rain 3 load(s) => 25 reviews loaded
# Singin' in the Rain 4 load(s) => 25 reviews loaded
# Singin' in the Rain 5 load(s) => 25 reviews loaded
# Requiem for a Dream 1 load(s) => 25 reviews loaded
# Requiem for a Dream 2 load(s) => 24 reviews loaded
# Requiem for a Dream 3 load(s) => 25 reviews loaded
# Requiem for a Dream 4 load(s) => 25 reviews loaded
# Requiem for a Dream 5 load(s) => 25 reviews loaded
# High and Low 1 load(s) => 25 reviews loaded
# High and Low 2 load(s) => 25 reviews loaded
# High and Low 3 load(s) => 25 reviews loaded
# High and Low 4 load(s) => 25 reviews loaded
# High and Low 5 load(s) => 25 reviews loaded
# Toy Story 3 1 load(s) => 25 reviews loaded
# Toy Story 3 2 load(s) => 25 reviews loaded
# Toy Story 3 3 load(s) => 25 reviews loaded
# Toy Story 3 4 load(s) => 25 reviews loaded
# Toy Story 3 5 load(s) => 25 reviews loaded
# Capernaum 1 load(s) => 25 reviews loaded
# Capernaum 2 load(s) => 25 reviews loaded
# Capernaum 3 load(s) => 25 reviews loaded
# Capernaum 4 load(s) => 25 reviews loaded
# Capernaum 5 load(s) => 25 reviews loaded
# Star Wars: Episode VI - Return of the Jedi 1 load(s) => 25 reviews loaded
# Star Wars: Episode VI - Return of the Jedi 2 load(s) => 25 reviews loaded
# Star Wars: Episode VI - Return of the Jedi 3 load(s) => 25 reviews loaded
# Star Wars: Episode VI - Return of the Jedi 4 load(s) => 25 reviews loaded
# Star Wars: Episode VI - Return of the Jedi 5 load(s) => 25 reviews loaded
# Eternal Sunshine of the Spotless Mind 1 load(s) => 25 reviews loaded
# Eternal Sunshine of the Spotless Mind 2 load(s) => 25 reviews loaded
# Eternal Sunshine of the Spotless Mind 3 load(s) => 25 reviews loaded
# Eternal Sunshine of the Spotless Mind 4 load(s) => 25 reviews loaded
# Eternal Sunshine of the Spotless Mind 5 load(s) => 25 reviews loaded
# 2001: A Space Odyssey 1 load(s) => 25 reviews loaded
# 2001: A Space Odyssey 2 load(s) => 25 reviews loaded
# 2001: A Space Odyssey 3 load(s) => 25 reviews loaded
# 2001: A Space Odyssey 4 load(s) => 24 reviews loaded
# 2001: A Space Odyssey 5 load(s) => 24 reviews loaded
# Reservoir Dogs 1 load(s) => 24 reviews loaded
# Reservoir Dogs 2 load(s) => 24 reviews loaded
# Reservoir Dogs 3 load(s) => 25 reviews loaded
# Reservoir Dogs 4 load(s) => 25 reviews loaded
# Reservoir Dogs 5 load(s) => 24 reviews loaded
# Come and See 1 load(s) => 25 reviews loaded
# Come and See 2 load(s) => 25 reviews loaded
# Come and See 3 load(s) => 25 reviews loaded
# Come and See 4 load(s) => 25 reviews loaded
# Come and See 5 load(s) => 25 reviews loaded
# The Hunt 1 load(s) => 25 reviews loaded
# The Hunt 2 load(s) => 25 reviews loaded
# The Hunt 3 load(s) => 25 reviews loaded
# The Hunt 4 load(s) => 25 reviews loaded
# The Hunt 5 load(s) => 25 reviews loaded
# Citizen Kane 1 load(s) => 25 reviews loaded
# Citizen Kane 2 load(s) => 25 reviews loaded
# Citizen Kane 3 load(s) => 24 reviews loaded
# Citizen Kane 4 load(s) => 25 reviews loaded
# Citizen Kane 5 load(s) => 25 reviews loaded
# M 1 load(s) => 25 reviews loaded
# M 2 load(s) => 25 reviews loaded
# M 3 load(s) => 25 reviews loaded
# M 4 load(s) => 25 reviews loaded
# M 5 load(s) => 25 reviews loaded
# Lawrence of Arabia 1 load(s) => 25 reviews loaded
# Lawrence of Arabia 2 load(s) => 25 reviews loaded
# Lawrence of Arabia 3 load(s) => 25 reviews loaded
# Lawrence of Arabia 4 load(s) => 25 reviews loaded
# Lawrence of Arabia 5 load(s) => 25 reviews loaded
# North by Northwest 1 load(s) => 25 reviews loaded
# North by Northwest 2 load(s) => 24 reviews loaded
# North by Northwest 3 load(s) => 25 reviews loaded
# North by Northwest 4 load(s) => 25 reviews loaded
# North by Northwest 5 load(s) => 25 reviews loaded
# Vertigo 1 load(s) => 25 reviews loaded
# Vertigo 2 load(s) => 25 reviews loaded
# Vertigo 3 load(s) => 25 reviews loaded
# Vertigo 4 load(s) => 25 reviews loaded
# Vertigo 5 load(s) => 25 reviews loaded
# Ikiru 1 load(s) => 25 reviews loaded
# Ikiru 2 load(s) => 25 reviews loaded
# Ikiru 3 load(s) => 25 reviews loaded
# Ikiru 4 load(s) => 25 reviews loaded
# Ikiru 5 load(s) => 25 reviews loaded
# The Apartment 1 load(s) => 25 reviews loaded
# The Apartment 2 load(s) => 25 reviews loaded
# The Apartment 3 load(s) => 25 reviews loaded
# The Apartment 4 load(s) => 25 reviews loaded
# The Apartment 5 load(s) => 25 reviews loaded
# Amélie 1 load(s) => 25 reviews loaded
# Amélie 2 load(s) => 25 reviews loaded
# Amélie 3 load(s) => 25 reviews loaded
# Amélie 4 load(s) => 25 reviews loaded
# Amélie 5 load(s) => 25 reviews loaded
# A Clockwork Orange 1 load(s) => 25 reviews loaded
# A Clockwork Orange 2 load(s) => 25 reviews loaded
# A Clockwork Orange 3 load(s) => 25 reviews loaded
# A Clockwork Orange 4 load(s) => 24 reviews loaded
# A Clockwork Orange 5 load(s) => 25 reviews loaded
# Double Indemnity 1 load(s) => 25 reviews loaded
# Double Indemnity 2 load(s) => 25 reviews loaded
# Double Indemnity 3 load(s) => 25 reviews loaded
# Double Indemnity 4 load(s) => 25 reviews loaded
# Double Indemnity 5 load(s) => 25 reviews loaded
# Full Metal Jacket 1 load(s) => 24 reviews loaded
# Full Metal Jacket 2 load(s) => 25 reviews loaded
# Full Metal Jacket 3 load(s) => 25 reviews loaded
# Full Metal Jacket 4 load(s) => 25 reviews loaded
# Full Metal Jacket 5 load(s) => 25 reviews loaded
# Scarface 1 load(s) => 25 reviews loaded
# Scarface 2 load(s) => 25 reviews loaded
# Scarface 3 load(s) => 25 reviews loaded
# Scarface 4 load(s) => 25 reviews loaded
# Scarface 5 load(s) => 25 reviews loaded
# Hamilton 1 load(s) => 25 reviews loaded
# Hamilton 2 load(s) => 25 reviews loaded
# Hamilton 3 load(s) => 25 reviews loaded
# Hamilton 4 load(s) => 25 reviews loaded
# Hamilton 5 load(s) => 25 reviews loaded
# Top Gun: Maverick 1 load(s) => 25 reviews loaded
# Top Gun: Maverick 2 load(s) => 25 reviews loaded
# Top Gun: Maverick 3 load(s) => 25 reviews loaded
# Top Gun: Maverick 4 load(s) => 25 reviews loaded
# Top Gun: Maverick 5 load(s) => 25 reviews loaded
# Incendies 1 load(s) => 25 reviews loaded
# Incendies 2 load(s) => 25 reviews loaded
# Incendies 3 load(s) => 25 reviews loaded
# Incendies 4 load(s) => 25 reviews loaded
# Incendies 5 load(s) => 25 reviews loaded
# To Kill a Mockingbird 1 load(s) => 25 reviews loaded
# To Kill a Mockingbird 2 load(s) => 25 reviews loaded
# To Kill a Mockingbird 3 load(s) => 25 reviews loaded
# To Kill a Mockingbird 4 load(s) => 25 reviews loaded
# To Kill a Mockingbird 5 load(s) => 25 reviews loaded
# Heat 1 load(s) => 25 reviews loaded
# Heat 2 load(s) => 25 reviews loaded
# Heat 3 load(s) => 25 reviews loaded
# Heat 4 load(s) => 25 reviews loaded
# Heat 5 load(s) => 25 reviews loaded
# The Sting 1 load(s) => 25 reviews loaded
# The Sting 2 load(s) => 25 reviews loaded
# The Sting 3 load(s) => 25 reviews loaded
# The Sting 4 load(s) => 25 reviews loaded
# The Sting 5 load(s) => 25 reviews loaded
# Up 1 load(s) => 25 reviews loaded
# Up 2 load(s) => 25 reviews loaded
# Up 3 load(s) => 25 reviews loaded
# Up 4 load(s) => 25 reviews loaded
# Up 5 load(s) => 25 reviews loaded
# A Separation 1 load(s) => 25 reviews loaded
# A Separation 2 load(s) => 25 reviews loaded
# A Separation 3 load(s) => 25 reviews loaded
# A Separation 4 load(s) => 25 reviews loaded
# A Separation 5 load(s) => 25 reviews loaded
# Metropolis 1 load(s) => 25 reviews loaded
# Metropolis 2 load(s) => 25 reviews loaded
# Metropolis 3 load(s) => 25 reviews loaded
# Metropolis 4 load(s) => 25 reviews loaded
# Metropolis 5 load(s) => 25 reviews loaded
# Taxi Driver 1 load(s) => 25 reviews loaded
# Taxi Driver 2 load(s) => 25 reviews loaded
# Taxi Driver 3 load(s) => 25 reviews loaded
# Taxi Driver 4 load(s) => 25 reviews loaded
# Taxi Driver 5 load(s) => 25 reviews loaded
# L.A. Confidential 1 load(s) => 25 reviews loaded
# L.A. Confidential 2 load(s) => 25 reviews loaded
# L.A. Confidential 3 load(s) => 25 reviews loaded
# L.A. Confidential 4 load(s) => 25 reviews loaded
# L.A. Confidential 5 load(s) => 25 reviews loaded
# Die Hard 1 load(s) => 25 reviews loaded
# Die Hard 2 load(s) => 25 reviews loaded
# Die Hard 3 load(s) => 25 reviews loaded
# Die Hard 4 load(s) => 25 reviews loaded
# Die Hard 5 load(s) => 25 reviews loaded
# Snatch 1 load(s) => 25 reviews loaded
# Snatch 2 load(s) => 25 reviews loaded
# Snatch 3 load(s) => 24 reviews loaded
# Snatch 4 load(s) => 25 reviews loaded
# Snatch 5 load(s) => 25 reviews loaded
# Indiana Jones and the Last Crusade 1 load(s) => 25 reviews loaded
# Indiana Jones and the Last Crusade 2 load(s) => 24 reviews loaded
# Indiana Jones and the Last Crusade 3 load(s) => 25 reviews loaded
# Indiana Jones and the Last Crusade 4 load(s) => 25 reviews loaded
# Indiana Jones and the Last Crusade 5 load(s) => 25 reviews loaded
# Bicycle Thieves 1 load(s) => 25 reviews loaded
# Bicycle Thieves 2 load(s) => 25 reviews loaded
# Bicycle Thieves 3 load(s) => 25 reviews loaded
# Bicycle Thieves 4 load(s) => 25 reviews loaded
# Bicycle Thieves 5 load(s) => 25 reviews loaded
# Like Stars on Earth 1 load(s) => 25 reviews loaded
# Like Stars on Earth 2 load(s) => 25 reviews loaded
# Like Stars on Earth 3 load(s) => 25 reviews loaded
# Like Stars on Earth 4 load(s) => 25 reviews loaded
# Like Stars on Earth 5 load(s) => 25 reviews loaded
# 1917 1 load(s) => 25 reviews loaded
# 1917 2 load(s) => 25 reviews loaded
# 1917 3 load(s) => 25 reviews loaded
# 1917 4 load(s) => 25 reviews loaded
# 1917 5 load(s) => 25 reviews loaded
# Downfall 1 load(s) => 25 reviews loaded
# Downfall 2 load(s) => 25 reviews loaded
# Downfall 3 load(s) => 25 reviews loaded
# Downfall 4 load(s) => 25 reviews loaded
# Downfall 5 load(s) => 25 reviews loaded
# Dangal 1 load(s) => 25 reviews loaded
# Dangal 2 load(s) => 25 reviews loaded
# Dangal 3 load(s) => 25 reviews loaded
# Dangal 4 load(s) => 24 reviews loaded
# Dangal 5 load(s) => 25 reviews loaded
# For a Few Dollars More 1 load(s) => 25 reviews loaded
# For a Few Dollars More 2 load(s) => 25 reviews loaded
# For a Few Dollars More 3 load(s) => 25 reviews loaded
# For a Few Dollars More 4 load(s) => 24 reviews loaded
# For a Few Dollars More 5 load(s) => 25 reviews loaded
# Batman Begins 1 load(s) => 25 reviews loaded
# Batman Begins 2 load(s) => 25 reviews loaded
# Batman Begins 3 load(s) => 25 reviews loaded
# Batman Begins 4 load(s) => 25 reviews loaded
# Batman Begins 5 load(s) => 25 reviews loaded
# The Kid 1 load(s) => 25 reviews loaded
# The Kid 2 load(s) => 25 reviews loaded
# The Kid 3 load(s) => 25 reviews loaded
# The Kid 4 load(s) => 25 reviews loaded
# The Kid 5 load(s) => 25 reviews loaded
# Some Like It Hot 1 load(s) => 25 reviews loaded
# Some Like It Hot 2 load(s) => 25 reviews loaded
# Some Like It Hot 3 load(s) => 25 reviews loaded
# Some Like It Hot 4 load(s) => 25 reviews loaded
# Some Like It Hot 5 load(s) => 25 reviews loaded
# The Father 1 load(s) => 25 reviews loaded
# The Father 2 load(s) => 25 reviews loaded
# The Father 3 load(s) => 25 reviews loaded
# The Father 4 load(s) => 25 reviews loaded
# The Father 5 load(s) => 25 reviews loaded
# All About Eve 1 load(s) => 25 reviews loaded
# All About Eve 2 load(s) => 25 reviews loaded
# All About Eve 3 load(s) => 25 reviews loaded
# All About Eve 4 load(s) => 25 reviews loaded
# All About Eve 5 load(s) => 24 reviews loaded
# The Wolf of Wall Street 1 load(s) => 25 reviews loaded
# The Wolf of Wall Street 2 load(s) => 25 reviews loaded
# The Wolf of Wall Street 3 load(s) => 25 reviews loaded
# The Wolf of Wall Street 4 load(s) => 25 reviews loaded
# The Wolf of Wall Street 5 load(s) => 25 reviews loaded
# Green Book 1 load(s) => 25 reviews loaded
# Green Book 2 load(s) => 25 reviews loaded
# Green Book 3 load(s) => 25 reviews loaded
# Green Book 4 load(s) => 25 reviews loaded
# Green Book 5 load(s) => 25 reviews loaded
# Judgment at Nuremberg 1 load(s) => 24 reviews loaded
# Judgment at Nuremberg 2 load(s) => 25 reviews loaded
# Judgment at Nuremberg 3 load(s) => 25 reviews loaded
# Judgment at Nuremberg 4 load(s) => 25 reviews loaded
# Judgment at Nuremberg 5 load(s) => 25 reviews loaded
# Casino 1 load(s) => 25 reviews loaded
# Casino 2 load(s) => 25 reviews loaded
# Casino 3 load(s) => 25 reviews loaded
# Casino 4 load(s) => 24 reviews loaded
# Casino 5 load(s) => 25 reviews loaded
# Ran 1 load(s) => 25 reviews loaded
# Ran 2 load(s) => 25 reviews loaded
# Ran 3 load(s) => 24 reviews loaded
# Ran 4 load(s) => 25 reviews loaded
# Ran 5 load(s) => 25 reviews loaded
# Pan's Labyrinth 1 load(s) => 25 reviews loaded
# Pan's Labyrinth 2 load(s) => 25 reviews loaded
# Pan's Labyrinth 3 load(s) => 25 reviews loaded
# Pan's Labyrinth 4 load(s) => 25 reviews loaded
# Pan's Labyrinth 5 load(s) => 25 reviews loaded
# The Truman Show 1 load(s) => 25 reviews loaded
# The Truman Show 2 load(s) => 25 reviews loaded
# The Truman Show 3 load(s) => 25 reviews loaded
# The Truman Show 4 load(s) => 24 reviews loaded
# The Truman Show 5 load(s) => 25 reviews loaded
# There Will Be Blood 1 load(s) => 25 reviews loaded
# There Will Be Blood 2 load(s) => 25 reviews loaded
# There Will Be Blood 3 load(s) => 25 reviews loaded
# There Will Be Blood 4 load(s) => 25 reviews loaded
# There Will Be Blood 5 load(s) => 25 reviews loaded
# Unforgiven 1 load(s) => 25 reviews loaded
# Unforgiven 2 load(s) => 25 reviews loaded
# Unforgiven 3 load(s) => 25 reviews loaded
# Unforgiven 4 load(s) => 24 reviews loaded
# Unforgiven 5 load(s) => 24 reviews loaded
# The Sixth Sense 1 load(s) => 25 reviews loaded
# The Sixth Sense 2 load(s) => 25 reviews loaded
# The Sixth Sense 3 load(s) => 25 reviews loaded
# The Sixth Sense 4 load(s) => 25 reviews loaded
# The Sixth Sense 5 load(s) => 25 reviews loaded
# Shutter Island 1 load(s) => 25 reviews loaded
# Shutter Island 2 load(s) => 25 reviews loaded
# Shutter Island 3 load(s) => 25 reviews loaded
# Shutter Island 4 load(s) => 25 reviews loaded
# Shutter Island 5 load(s) => 25 reviews loaded
# A Beautiful Mind 1 load(s) => 25 reviews loaded
# A Beautiful Mind 2 load(s) => 25 reviews loaded
# A Beautiful Mind 3 load(s) => 25 reviews loaded
# A Beautiful Mind 4 load(s) => 25 reviews loaded
# A Beautiful Mind 5 load(s) => 25 reviews loaded
# Jurassic Park 1 load(s) => 25 reviews loaded
# Jurassic Park 2 load(s) => 25 reviews loaded
# Jurassic Park 3 load(s) => 25 reviews loaded
# Jurassic Park 4 load(s) => 25 reviews loaded
# Jurassic Park 5 load(s) => 25 reviews loaded
# Yojimbo 1 load(s) => 25 reviews loaded
# Yojimbo 2 load(s) => 24 reviews loaded
# Yojimbo 3 load(s) => 25 reviews loaded
# Yojimbo 4 load(s) => 25 reviews loaded
# Yojimbo 5 load(s) => 25 reviews loaded
# The Treasure of the Sierra Madre 1 load(s) => 25 reviews loaded
# The Treasure of the Sierra Madre 2 load(s) => 25 reviews loaded
# The Treasure of the Sierra Madre 3 load(s) => 25 reviews loaded
# The Treasure of the Sierra Madre 4 load(s) => 25 reviews loaded
# The Treasure of the Sierra Madre 5 load(s) => 25 reviews loaded
# Monty Python and the Holy Grail 1 load(s) => 25 reviews loaded
# Monty Python and the Holy Grail 2 load(s) => 25 reviews loaded
# Monty Python and the Holy Grail 3 load(s) => 25 reviews loaded
# Monty Python and the Holy Grail 4 load(s) => 24 reviews loaded
# Monty Python and the Holy Grail 5 load(s) => 25 reviews loaded
# The Great Escape 1 load(s) => 25 reviews loaded
# The Great Escape 2 load(s) => 25 reviews loaded
# The Great Escape 3 load(s) => 25 reviews loaded
# The Great Escape 4 load(s) => 25 reviews loaded
# The Great Escape 5 load(s) => 25 reviews loaded
# No Country for Old Men 1 load(s) => 25 reviews loaded
# No Country for Old Men 2 load(s) => 25 reviews loaded
# No Country for Old Men 3 load(s) => 25 reviews loaded
# No Country for Old Men 4 load(s) => 25 reviews loaded
# No Country for Old Men 5 load(s) => 25 reviews loaded
# Kill Bill: Vol. 1 1 load(s) => 25 reviews loaded
# Kill Bill: Vol. 1 2 load(s) => 25 reviews loaded
# Kill Bill: Vol. 1 3 load(s) => 25 reviews loaded
# Kill Bill: Vol. 1 4 load(s) => 25 reviews loaded
# Kill Bill: Vol. 1 5 load(s) => 25 reviews loaded
# Rashomon 1 load(s) => 25 reviews loaded
# Rashomon 2 load(s) => 25 reviews loaded
# Rashomon 3 load(s) => 25 reviews loaded
# Rashomon 4 load(s) => 25 reviews loaded
# Rashomon 5 load(s) => 25 reviews loaded
# Spider-Man: No Way Home 1 load(s) => 25 reviews loaded
# Spider-Man: No Way Home 2 load(s) => 25 reviews loaded
# Spider-Man: No Way Home 3 load(s) => 25 reviews loaded
# Spider-Man: No Way Home 4 load(s) => 25 reviews loaded
# Spider-Man: No Way Home 5 load(s) => 25 reviews loaded
# The Thing 1 load(s) => 25 reviews loaded
# The Thing 2 load(s) => 25 reviews loaded
# The Thing 3 load(s) => 25 reviews loaded
# The Thing 4 load(s) => 25 reviews loaded
# The Thing 5 load(s) => 25 reviews loaded
# Finding Nemo 1 load(s) => 25 reviews loaded
# Finding Nemo 2 load(s) => 25 reviews loaded
# Finding Nemo 3 load(s) => 25 reviews loaded
# Finding Nemo 4 load(s) => 24 reviews loaded
# Finding Nemo 5 load(s) => 25 reviews loaded
# The Elephant Man 1 load(s) => 25 reviews loaded
# The Elephant Man 2 load(s) => 25 reviews loaded
# The Elephant Man 3 load(s) => 25 reviews loaded
# The Elephant Man 4 load(s) => 24 reviews loaded
# The Elephant Man 5 load(s) => 25 reviews loaded
# Chinatown 1 load(s) => 25 reviews loaded
# Chinatown 2 load(s) => 25 reviews loaded
# Chinatown 3 load(s) => 25 reviews loaded
# Chinatown 4 load(s) => 25 reviews loaded
# Chinatown 5 load(s) => 25 reviews loaded
# Raging Bull 1 load(s) => 25 reviews loaded
# Raging Bull 2 load(s) => 24 reviews loaded
# Raging Bull 3 load(s) => 25 reviews loaded
# Raging Bull 4 load(s) => 25 reviews loaded
# Raging Bull 5 load(s) => 25 reviews loaded
# V for Vendetta 1 load(s) => 25 reviews loaded
# V for Vendetta 2 load(s) => 25 reviews loaded
# V for Vendetta 3 load(s) => 25 reviews loaded
# V for Vendetta 4 load(s) => 25 reviews loaded
# V for Vendetta 5 load(s) => 25 reviews loaded
# Gone with the Wind 1 load(s) => 25 reviews loaded
# Gone with the Wind 2 load(s) => 25 reviews loaded
# Gone with the Wind 3 load(s) => 25 reviews loaded
# Gone with the Wind 4 load(s) => 25 reviews loaded
# Gone with the Wind 5 load(s) => 25 reviews loaded
# Lock, Stock and Two Smoking Barrels 1 load(s) => 25 reviews loaded
# Lock, Stock and Two Smoking Barrels 2 load(s) => 25 reviews loaded
# Lock, Stock and Two Smoking Barrels 3 load(s) => 24 reviews loaded
# Lock, Stock and Two Smoking Barrels 4 load(s) => 25 reviews loaded
# Lock, Stock and Two Smoking Barrels 5 load(s) => 25 reviews loaded
# Inside Out 1 load(s) => 25 reviews loaded
# Inside Out 2 load(s) => 25 reviews loaded
# Inside Out 3 load(s) => 25 reviews loaded
# Inside Out 4 load(s) => 25 reviews loaded
# Inside Out 5 load(s) => 25 reviews loaded
# Dial M for Murder 1 load(s) => 25 reviews loaded
# Dial M for Murder 2 load(s) => 25 reviews loaded
# Dial M for Murder 3 load(s) => 25 reviews loaded
# Dial M for Murder 4 load(s) => 25 reviews loaded
# Dial M for Murder 5 load(s) => 25 reviews loaded
# The Secret in Their Eyes 1 load(s) => 25 reviews loaded
# The Secret in Their Eyes 2 load(s) => 25 reviews loaded
# The Secret in Their Eyes 3 load(s) => 25 reviews loaded
# The Secret in Their Eyes 4 load(s) => 25 reviews loaded
# The Secret in Their Eyes 5 load(s) => 25 reviews loaded
# Howl's Moving Castle 1 load(s) => 25 reviews loaded
# Howl's Moving Castle 2 load(s) => 25 reviews loaded
# Howl's Moving Castle 3 load(s) => 25 reviews loaded
# Howl's Moving Castle 4 load(s) => 25 reviews loaded
# Howl's Moving Castle 5 load(s) => 25 reviews loaded
# Three Billboards Outside Ebbing, Missouri 1 load(s) => 25 reviews loaded
# Three Billboards Outside Ebbing, Missouri 2 load(s) => 25 reviews loaded
# Three Billboards Outside Ebbing, Missouri 3 load(s) => 25 reviews loaded
# Three Billboards Outside Ebbing, Missouri 4 load(s) => 25 reviews loaded
# Three Billboards Outside Ebbing, Missouri 5 load(s) => 25 reviews loaded
# The Bridge on the River Kwai 1 load(s) => 25 reviews loaded
# The Bridge on the River Kwai 2 load(s) => 25 reviews loaded
# The Bridge on the River Kwai 3 load(s) => 24 reviews loaded
# The Bridge on the River Kwai 4 load(s) => 25 reviews loaded
# The Bridge on the River Kwai 5 load(s) => 25 reviews loaded
# Trainspotting 1 load(s) => 25 reviews loaded
# Trainspotting 2 load(s) => 24 reviews loaded
# Trainspotting 3 load(s) => 25 reviews loaded
# Trainspotting 4 load(s) => 24 reviews loaded
# Trainspotting 5 load(s) => 25 reviews loaded
# Prisoners 1 load(s) => 25 reviews loaded
# Prisoners 2 load(s) => 25 reviews loaded
# Prisoners 3 load(s) => 25 reviews loaded
# Prisoners 4 load(s) => 25 reviews loaded
# Prisoners 5 load(s) => 25 reviews loaded
# Warrior 1 load(s) => 25 reviews loaded
# Warrior 2 load(s) => 25 reviews loaded
# Warrior 3 load(s) => 25 reviews loaded
# Warrior 4 load(s) => 25 reviews loaded
# Warrior 5 load(s) => 25 reviews loaded
# Fargo 1 load(s) => 25 reviews loaded
# Fargo 2 load(s) => 25 reviews loaded
# Fargo 3 load(s) => 25 reviews loaded
# Fargo 4 load(s) => 25 reviews loaded
# Fargo 5 load(s) => 24 reviews loaded
# Gran Torino 1 load(s) => 25 reviews loaded
# Gran Torino 2 load(s) => 25 reviews loaded
# Gran Torino 3 load(s) => 25 reviews loaded
# Gran Torino 4 load(s) => 25 reviews loaded
# Gran Torino 5 load(s) => 25 reviews loaded
# My Neighbor Totoro 1 load(s) => 25 reviews loaded
# My Neighbor Totoro 2 load(s) => 25 reviews loaded
# My Neighbor Totoro 3 load(s) => 25 reviews loaded
# My Neighbor Totoro 4 load(s) => 24 reviews loaded
# My Neighbor Totoro 5 load(s) => 25 reviews loaded
# Catch Me If You Can 1 load(s) => 25 reviews loaded
# Catch Me If You Can 2 load(s) => 25 reviews loaded
# Catch Me If You Can 3 load(s) => 25 reviews loaded
# Catch Me If You Can 4 load(s) => 25 reviews loaded
# Catch Me If You Can 5 load(s) => 25 reviews loaded
# Million Dollar Baby 1 load(s) => 25 reviews loaded
# Million Dollar Baby 2 load(s) => 25 reviews loaded
# Million Dollar Baby 3 load(s) => 25 reviews loaded
# Million Dollar Baby 4 load(s) => 25 reviews loaded
# Million Dollar Baby 5 load(s) => 25 reviews loaded
# Children of Heaven 1 load(s) => 25 reviews loaded
# Children of Heaven 2 load(s) => 25 reviews loaded
# Children of Heaven 3 load(s) => 25 reviews loaded
# Children of Heaven 4 load(s) => 25 reviews loaded
# Children of Heaven 5 load(s) => 25 reviews loaded
# Blade Runner 1 load(s) => 25 reviews loaded
# Blade Runner 2 load(s) => 25 reviews loaded
# Blade Runner 3 load(s) => 25 reviews loaded
# Blade Runner 4 load(s) => 25 reviews loaded
# Blade Runner 5 load(s) => 25 reviews loaded
# The Gold Rush 1 load(s) => 25 reviews loaded
# The Gold Rush 2 load(s) => 25 reviews loaded
# The Gold Rush 3 load(s) => 25 reviews loaded
# The Gold Rush 4 load(s) => 25 reviews loaded
# The Gold Rush 5 load(s) => 25 reviews loaded
# Before Sunrise 1 load(s) => 25 reviews loaded
# Before Sunrise 2 load(s) => 25 reviews loaded
# Before Sunrise 3 load(s) => 25 reviews loaded
# Before Sunrise 4 load(s) => 25 reviews loaded
# Before Sunrise 5 load(s) => 25 reviews loaded
# Klaus 1 load(s) => 25 reviews loaded
# Klaus 2 load(s) => 25 reviews loaded
# Klaus 3 load(s) => 25 reviews loaded
# Klaus 4 load(s) => 25 reviews loaded
# Klaus 5 load(s) => 25 reviews loaded
# 12 Years a Slave 1 load(s) => 25 reviews loaded
# 12 Years a Slave 2 load(s) => 25 reviews loaded
# 12 Years a Slave 3 load(s) => 25 reviews loaded
# 12 Years a Slave 4 load(s) => 25 reviews loaded
# 12 Years a Slave 5 load(s) => 25 reviews loaded
# Harry Potter and the Deathly Hallows: Part 2 1 load(s) => 25 reviews loaded
# Harry Potter and the Deathly Hallows: Part 2 2 load(s) => 25 reviews loaded
# Harry Potter and the Deathly Hallows: Part 2 3 load(s) => 25 reviews loaded
# Harry Potter and the Deathly Hallows: Part 2 4 load(s) => 25 reviews loaded
# Harry Potter and the Deathly Hallows: Part 2 5 load(s) => 25 reviews loaded
# On the Waterfront 1 load(s) => 25 reviews loaded
# On the Waterfront 2 load(s) => 25 reviews loaded
# On the Waterfront 3 load(s) => 25 reviews loaded
# On the Waterfront 4 load(s) => 25 reviews loaded
# On the Waterfront 5 load(s) => 25 reviews loaded
# Ben-Hur 1 load(s) => 25 reviews loaded
# Ben-Hur 2 load(s) => 24 reviews loaded
# Ben-Hur 3 load(s) => 25 reviews loaded
# Ben-Hur 4 load(s) => 25 reviews loaded
# Ben-Hur 5 load(s) => 25 reviews loaded
# The Grand Budapest Hotel 1 load(s) => 25 reviews loaded
# The Grand Budapest Hotel 2 load(s) => 25 reviews loaded
# The Grand Budapest Hotel 3 load(s) => 25 reviews loaded
# The Grand Budapest Hotel 4 load(s) => 25 reviews loaded
# The Grand Budapest Hotel 5 load(s) => 25 reviews loaded
# Gone Girl 1 load(s) => 25 reviews loaded
# Gone Girl 2 load(s) => 25 reviews loaded
# Gone Girl 3 load(s) => 25 reviews loaded
# Gone Girl 4 load(s) => 25 reviews loaded
# Gone Girl 5 load(s) => 25 reviews loaded
# Wild Strawberries 1 load(s) => 25 reviews loaded
# Wild Strawberries 2 load(s) => 25 reviews loaded
# Wild Strawberries 3 load(s) => 25 reviews loaded
# Wild Strawberries 4 load(s) => 25 reviews loaded
# Wild Strawberries 5 load(s) => 25 reviews loaded
# The General 1 load(s) => 24 reviews loaded
# The General 2 load(s) => 25 reviews loaded
# The General 3 load(s) => 25 reviews loaded
# The General 4 load(s) => 25 reviews loaded
# The General 5 load(s) => 25 reviews loaded
# The Third Man 1 load(s) => 25 reviews loaded
# The Third Man 2 load(s) => 25 reviews loaded
# The Third Man 3 load(s) => 25 reviews loaded
# The Third Man 4 load(s) => 25 reviews loaded
# The Third Man 5 load(s) => 24 reviews loaded
# In the Name of the Father 1 load(s) => 24 reviews loaded
# In the Name of the Father 2 load(s) => 25 reviews loaded
# In the Name of the Father 3 load(s) => 25 reviews loaded
# In the Name of the Father 4 load(s) => 25 reviews loaded
# In the Name of the Father 5 load(s) => 25 reviews loaded
# The Deer Hunter 1 load(s) => 25 reviews loaded
# The Deer Hunter 2 load(s) => 25 reviews loaded
# The Deer Hunter 3 load(s) => 25 reviews loaded
# The Deer Hunter 4 load(s) => 24 reviews loaded
# The Deer Hunter 5 load(s) => 25 reviews loaded
# Barry Lyndon 1 load(s) => 24 reviews loaded
# Barry Lyndon 2 load(s) => 25 reviews loaded
# Barry Lyndon 3 load(s) => 25 reviews loaded
# Barry Lyndon 4 load(s) => 25 reviews loaded
# Barry Lyndon 5 load(s) => 25 reviews loaded
# Hacksaw Ridge 1 load(s) => 25 reviews loaded
# Hacksaw Ridge 2 load(s) => 25 reviews loaded
# Hacksaw Ridge 3 load(s) => 25 reviews loaded
# Hacksaw Ridge 4 load(s) => 25 reviews loaded
# Hacksaw Ridge 5 load(s) => 25 reviews loaded
# The Wages of Fear 1 load(s) => 25 reviews loaded
# The Wages of Fear 2 load(s) => 25 reviews loaded
# The Wages of Fear 3 load(s) => 25 reviews loaded
# The Wages of Fear 4 load(s) => 25 reviews loaded
# The Wages of Fear 5 load(s) => 25 reviews loaded
# Memories of Murder 1 load(s) => 25 reviews loaded
# Memories of Murder 2 load(s) => 25 reviews loaded
# Memories of Murder 3 load(s) => 25 reviews loaded
# Memories of Murder 4 load(s) => 25 reviews loaded
# Memories of Murder 5 load(s) => 25 reviews loaded
# Sherlock Jr. 1 load(s) => 25 reviews loaded
# Sherlock Jr. 2 load(s) => 24 reviews loaded
# Sherlock Jr. 3 load(s) => 25 reviews loaded
# Sherlock Jr. 4 load(s) => 25 reviews loaded
# Sherlock Jr. 5 load(s) => 25 reviews loaded
# Wild Tales 1 load(s) => 25 reviews loaded
# Wild Tales 2 load(s) => 25 reviews loaded
# Wild Tales 3 load(s) => 25 reviews loaded
# Wild Tales 4 load(s) => 25 reviews loaded
# Wild Tales 5 load(s) => 25 reviews loaded
# Mr. Smith Goes to Washington 1 load(s) => 25 reviews loaded
# Mr. Smith Goes to Washington 2 load(s) => 25 reviews loaded
# Mr. Smith Goes to Washington 3 load(s) => 25 reviews loaded
# Mr. Smith Goes to Washington 4 load(s) => 25 reviews loaded
# Mr. Smith Goes to Washington 5 load(s) => 25 reviews loaded
# Mad Max: Fury Road 1 load(s) => 25 reviews loaded
# Mad Max: Fury Road 2 load(s) => 25 reviews loaded
# Mad Max: Fury Road 3 load(s) => 25 reviews loaded
# Mad Max: Fury Road 4 load(s) => 25 reviews loaded
# Mad Max: Fury Road 5 load(s) => 25 reviews loaded
# The Seventh Seal 1 load(s) => 25 reviews loaded
# The Seventh Seal 2 load(s) => 25 reviews loaded
# The Seventh Seal 3 load(s) => 25 reviews loaded
# The Seventh Seal 4 load(s) => 25 reviews loaded
# The Seventh Seal 5 load(s) => 25 reviews loaded
# Mary and Max 1 load(s) => 25 reviews loaded
# Mary and Max 2 load(s) => 25 reviews loaded
# Mary and Max 3 load(s) => 25 reviews loaded
# Mary and Max 4 load(s) => 25 reviews loaded
# Mary and Max 5 load(s) => 25 reviews loaded
# How to Train Your Dragon 1 load(s) => 25 reviews loaded
# How to Train Your Dragon 2 load(s) => 25 reviews loaded
# How to Train Your Dragon 3 load(s) => 24 reviews loaded
# How to Train Your Dragon 4 load(s) => 25 reviews loaded
# How to Train Your Dragon 5 load(s) => 24 reviews loaded
# Room 1 load(s) => 25 reviews loaded
# Room 2 load(s) => 25 reviews loaded
# Room 3 load(s) => 25 reviews loaded
# Room 4 load(s) => 25 reviews loaded
# Room 5 load(s) => 25 reviews loaded
# Monsters, Inc. 1 load(s) => 25 reviews loaded
# Monsters, Inc. 2 load(s) => 25 reviews loaded
# Monsters, Inc. 3 load(s) => 25 reviews loaded
# Monsters, Inc. 4 load(s) => 25 reviews loaded
# Monsters, Inc. 5 load(s) => 25 reviews loaded
# Jaws 1 load(s) => 25 reviews loaded
# Jaws 2 load(s) => 25 reviews loaded
# Jaws 3 load(s) => 25 reviews loaded
# Jaws 4 load(s) => 25 reviews loaded
# Jaws 5 load(s) => 25 reviews loaded
# Dead Poets Society 1 load(s) => 25 reviews loaded
# Dead Poets Society 2 load(s) => 25 reviews loaded
# Dead Poets Society 3 load(s) => 25 reviews loaded
# Dead Poets Society 4 load(s) => 25 reviews loaded
# Dead Poets Society 5 load(s) => 25 reviews loaded
# The Big Lebowski 1 load(s) => 25 reviews loaded
# The Big Lebowski 2 load(s) => 25 reviews loaded
# The Big Lebowski 3 load(s) => 25 reviews loaded
# The Big Lebowski 4 load(s) => 25 reviews loaded
# The Big Lebowski 5 load(s) => 25 reviews loaded
# Tokyo Story 1 load(s) => 25 reviews loaded
# Tokyo Story 2 load(s) => 24 reviews loaded
# Tokyo Story 3 load(s) => 25 reviews loaded
# Tokyo Story 4 load(s) => 25 reviews loaded
# Tokyo Story 5 load(s) => 25 reviews loaded
# The Passion of Joan of Arc 1 load(s) => 25 reviews loaded
# The Passion of Joan of Arc 2 load(s) => 25 reviews loaded
# The Passion of Joan of Arc 3 load(s) => 25 reviews loaded
# The Passion of Joan of Arc 4 load(s) => 25 reviews loaded
# The Passion of Joan of Arc 5 load(s) => 25 reviews loaded
# Hotel Rwanda 1 load(s) => 25 reviews loaded
# Hotel Rwanda 2 load(s) => 25 reviews loaded
# Hotel Rwanda 3 load(s) => 25 reviews loaded
# Hotel Rwanda 4 load(s) => 25 reviews loaded
# Hotel Rwanda 5 load(s) => 25 reviews loaded
# Ford v Ferrari 1 load(s) => 25 reviews loaded
# Ford v Ferrari 2 load(s) => 25 reviews loaded
# Ford v Ferrari 3 load(s) => 25 reviews loaded
# Ford v Ferrari 4 load(s) => 25 reviews loaded
# Ford v Ferrari 5 load(s) => 25 reviews loaded
# Rocky 1 load(s) => 25 reviews loaded
# Rocky 2 load(s) => 25 reviews loaded
# Rocky 3 load(s) => 25 reviews loaded
# Rocky 4 load(s) => 25 reviews loaded
# Rocky 5 load(s) => 25 reviews loaded
# Platoon 1 load(s) => 25 reviews loaded
# Platoon 2 load(s) => 25 reviews loaded
# Platoon 3 load(s) => 25 reviews loaded
# Platoon 4 load(s) => 25 reviews loaded
# Platoon 5 load(s) => 25 reviews loaded
# Ratatouille 1 load(s) => 25 reviews loaded
# Ratatouille 2 load(s) => 25 reviews loaded
# Ratatouille 3 load(s) => 25 reviews loaded
# Ratatouille 4 load(s) => 25 reviews loaded
# Ratatouille 5 load(s) => 25 reviews loaded
# Spotlight 1 load(s) => 25 reviews loaded
# Spotlight 2 load(s) => 25 reviews loaded
# Spotlight 3 load(s) => 25 reviews loaded
# Spotlight 4 load(s) => 25 reviews loaded
# Spotlight 5 load(s) => 25 reviews loaded
# The Terminator 1 load(s) => 25 reviews loaded
# The Terminator 2 load(s) => 25 reviews loaded
# The Terminator 3 load(s) => 25 reviews loaded
# The Terminator 4 load(s) => 25 reviews loaded
# The Terminator 5 load(s) => 25 reviews loaded
# Logan 1 load(s) => 25 reviews loaded
# Logan 2 load(s) => 25 reviews loaded
# Logan 3 load(s) => 25 reviews loaded
# Logan 4 load(s) => 25 reviews loaded
# Logan 5 load(s) => 25 reviews loaded
# Stand by Me 1 load(s) => 25 reviews loaded
# Stand by Me 2 load(s) => 25 reviews loaded
# Stand by Me 3 load(s) => 25 reviews loaded
# Stand by Me 4 load(s) => 24 reviews loaded
# Stand by Me 5 load(s) => 23 reviews loaded
# Rush 1 load(s) => 25 reviews loaded
# Rush 2 load(s) => 25 reviews loaded
# Rush 3 load(s) => 25 reviews loaded
# Rush 4 load(s) => 25 reviews loaded
# Rush 5 load(s) => 25 reviews loaded
# Network 1 load(s) => 25 reviews loaded
# Network 2 load(s) => 25 reviews loaded
# Network 3 load(s) => 25 reviews loaded
# Network 4 load(s) => 25 reviews loaded
# Network 5 load(s) => 25 reviews loaded
# Before Sunset 1 load(s) => 25 reviews loaded
# Before Sunset 2 load(s) => 25 reviews loaded
# Before Sunset 3 load(s) => 24 reviews loaded
# Before Sunset 4 load(s) => 25 reviews loaded
# Before Sunset 5 load(s) => 25 reviews loaded
# Into the Wild 1 load(s) => 25 reviews loaded
# Into the Wild 2 load(s) => 25 reviews loaded
# Into the Wild 3 load(s) => 25 reviews loaded
# Into the Wild 4 load(s) => 25 reviews loaded
# Into the Wild 5 load(s) => 24 reviews loaded
# The Wizard of Oz 1 load(s) => 25 reviews loaded
# The Wizard of Oz 2 load(s) => 25 reviews loaded
# The Wizard of Oz 3 load(s) => 25 reviews loaded
# The Wizard of Oz 4 load(s) => 25 reviews loaded
# The Wizard of Oz 5 load(s) => 25 reviews loaded
# Pather Panchali 1 load(s) => 25 reviews loaded
# Pather Panchali 2 load(s) => 25 reviews loaded
# Pather Panchali 3 load(s) => 25 reviews loaded
# Pather Panchali 4 load(s) => 25 reviews loaded
# Pather Panchali 5 load(s) => 25 reviews loaded
# Groundhog Day 1 load(s) => 25 reviews loaded
# Groundhog Day 2 load(s) => 25 reviews loaded
# Groundhog Day 3 load(s) => 25 reviews loaded
# Groundhog Day 4 load(s) => 25 reviews loaded
# Groundhog Day 5 load(s) => 25 reviews loaded
# The Best Years of Our Lives 1 load(s) => 25 reviews loaded
# The Best Years of Our Lives 2 load(s) => 25 reviews loaded
# The Best Years of Our Lives 3 load(s) => 25 reviews loaded
# The Best Years of Our Lives 4 load(s) => 25 reviews loaded
# The Best Years of Our Lives 5 load(s) => 25 reviews loaded
# The Exorcist 1 load(s) => 25 reviews loaded
# The Exorcist 2 load(s) => 25 reviews loaded
# The Exorcist 3 load(s) => 25 reviews loaded
# The Exorcist 4 load(s) => 25 reviews loaded
# The Exorcist 5 load(s) => 25 reviews loaded
# To Be or Not to Be 1 load(s) => 25 reviews loaded
# To Be or Not to Be 2 load(s) => 25 reviews loaded
# To Be or Not to Be 3 load(s) => 25 reviews loaded
# To Be or Not to Be 4 load(s) => 25 reviews loaded
# To Be or Not to Be 5 load(s) => 25 reviews loaded
# The Incredibles 1 load(s) => 24 reviews loaded
# The Incredibles 2 load(s) => 25 reviews loaded
# The Incredibles 3 load(s) => 25 reviews loaded
# The Incredibles 4 load(s) => 25 reviews loaded
# The Incredibles 5 load(s) => 25 reviews loaded
# La haine 1 load(s) => 24 reviews loaded
# La haine 2 load(s) => 25 reviews loaded
# La haine 3 load(s) => 25 reviews loaded
# La haine 4 load(s) => 25 reviews loaded
# La haine 5 load(s) => 25 reviews loaded
# Pirates of the Caribbean: The Curse of the Black Pearl 1 load(s) => 25 reviews loaded
# Pirates of the Caribbean: The Curse of the Black Pearl 2 load(s) => 25 reviews loaded
# Pirates of the Caribbean: The Curse of the Black Pearl 3 load(s) => 25 reviews loaded
# Pirates of the Caribbean: The Curse of the Black Pearl 4 load(s) => 25 reviews loaded
# Pirates of the Caribbean: The Curse of the Black Pearl 5 load(s) => 25 reviews loaded
# The Battle of Algiers 1 load(s) => 25 reviews loaded
# The Battle of Algiers 2 load(s) => 25 reviews loaded
# The Battle of Algiers 3 load(s) => 25 reviews loaded
# The Battle of Algiers 4 load(s) => 25 reviews loaded
# The Battle of Algiers 5 load(s) => 25 reviews loaded
# Jai Bhim 1 load(s) => 25 reviews loaded
# Jai Bhim 2 load(s) => 25 reviews loaded
# Jai Bhim 3 load(s) => 25 reviews loaded
# Jai Bhim 4 load(s) => 25 reviews loaded
# Jai Bhim 5 load(s) => 25 reviews loaded
# The Grapes of Wrath 1 load(s) => 25 reviews loaded
# The Grapes of Wrath 2 load(s) => 25 reviews loaded
# The Grapes of Wrath 3 load(s) => 24 reviews loaded
# The Grapes of Wrath 4 load(s) => 24 reviews loaded
# The Grapes of Wrath 5 load(s) => 25 reviews loaded
# Hachi: A Dog's Tale 1 load(s) => 25 reviews loaded
# Hachi: A Dog's Tale 2 load(s) => 24 reviews loaded
# Hachi: A Dog's Tale 3 load(s) => 25 reviews loaded
# Hachi: A Dog's Tale 4 load(s) => 25 reviews loaded
# Hachi: A Dog's Tale 5 load(s) => 25 reviews loaded
# My Father and My Son 1 load(s) => 25 reviews loaded
# My Father and My Son 2 load(s) => 25 reviews loaded
# My Father and My Son 3 load(s) => 25 reviews loaded
# My Father and My Son 4 load(s) => 25 reviews loaded
# My Father and My Son 5 load(s) => 25 reviews loaded
# Amores Perros 1 load(s) => 25 reviews loaded
# Amores Perros 2 load(s) => 25 reviews loaded
# Amores Perros 3 load(s) => 24 reviews loaded
# Amores Perros 4 load(s) => 24 reviews loaded
# Amores Perros 5 load(s) => 25 reviews loaded
# Rebecca 1 load(s) => 25 reviews loaded
# Rebecca 2 load(s) => 25 reviews loaded
# Rebecca 3 load(s) => 25 reviews loaded
# Rebecca 4 load(s) => 25 reviews loaded
# Rebecca 5 load(s) => 25 reviews loaded
# Cool Hand Luke 1 load(s) => 25 reviews loaded
# Cool Hand Luke 2 load(s) => 25 reviews loaded
# Cool Hand Luke 3 load(s) => 25 reviews loaded
# Cool Hand Luke 4 load(s) => 25 reviews loaded
# Cool Hand Luke 5 load(s) => 25 reviews loaded
# The Handmaiden 1 load(s) => 25 reviews loaded
# The Handmaiden 2 load(s) => 25 reviews loaded
# The Handmaiden 3 load(s) => 25 reviews loaded
# The Handmaiden 4 load(s) => 25 reviews loaded
# The Handmaiden 5 load(s) => 25 reviews loaded
# The 400 Blows 1 load(s) => 25 reviews loaded
# The 400 Blows 2 load(s) => 25 reviews loaded
# The 400 Blows 3 load(s) => 24 reviews loaded
# The 400 Blows 4 load(s) => 25 reviews loaded
# The 400 Blows 5 load(s) => 25 reviews loaded
# The Sound of Music 1 load(s) => 25 reviews loaded
# The Sound of Music 2 load(s) => 25 reviews loaded
# The Sound of Music 3 load(s) => 25 reviews loaded
# The Sound of Music 4 load(s) => 25 reviews loaded
# The Sound of Music 5 load(s) => 25 reviews loaded
# It Happened One Night 1 load(s) => 25 reviews loaded
# It Happened One Night 2 load(s) => 25 reviews loaded
# It Happened One Night 3 load(s) => 25 reviews loaded
# It Happened One Night 4 load(s) => 25 reviews loaded
# It Happened One Night 5 load(s) => 25 reviews loaded
# Persona 1 load(s) => 24 reviews loaded
# Persona 2 load(s) => 25 reviews loaded
# Persona 3 load(s) => 24 reviews loaded
# Persona 4 load(s) => 25 reviews loaded
# Persona 5 load(s) => 25 reviews loaded
# Life of Brian 1 load(s) => 25 reviews loaded
# Life of Brian 2 load(s) => 25 reviews loaded
# Life of Brian 3 load(s) => 25 reviews loaded
# Life of Brian 4 load(s) => 25 reviews loaded
# Life of Brian 5 load(s) => 25 reviews loaded
# The Iron Giant 1 load(s) => 25 reviews loaded
# The Iron Giant 2 load(s) => 25 reviews loaded
# The Iron Giant 3 load(s) => 25 reviews loaded
# The Iron Giant 4 load(s) => 25 reviews loaded
# The Iron Giant 5 load(s) => 25 reviews loaded
# Dersu Uzala 1 load(s) => 25 reviews loaded
# Dersu Uzala 2 load(s) => 25 reviews loaded
# Dersu Uzala 3 load(s) => 25 reviews loaded
# Dersu Uzala 4 load(s) => 25 reviews loaded
# Dersu Uzala 5 load(s) => 19 reviews loaded
# The Help 1 load(s) => 25 reviews loaded
# The Help 2 load(s) => 25 reviews loaded
# The Help 3 load(s) => 25 reviews loaded
# The Help 4 load(s) => 25 reviews loaded
# The Help 5 load(s) => 25 reviews loaded
# Aladdin 1 load(s) => 25 reviews loaded
# Aladdin 2 load(s) => 24 reviews loaded
# Aladdin 3 load(s) => 25 reviews loaded
# Aladdin 4 load(s) => 25 reviews loaded
# Aladdin 5 load(s) => 25 reviews loaded
# Gandhi 1 load(s) => 25 reviews loaded
# Gandhi 2 load(s) => 25 reviews loaded
# Gandhi 3 load(s) => 25 reviews loaded
# Gandhi 4 load(s) => 25 reviews loaded
# Gandhi 5 load(s) => 25 reviews loaded
# Dances with Wolves 1 load(s) => 24 reviews loaded
# Dances with Wolves 2 load(s) => 25 reviews loaded
# Dances with Wolves 3 load(s) => 25 reviews loaded
# Dances with Wolves 4 load(s) => 24 reviews loaded
# Dances with Wolves 5 load(s) => 25 reviews loaded
